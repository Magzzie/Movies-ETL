# %%
# Import dependencies
import json
import pandas as pd
import numpy as np
import re

# %%
# Build a file path to the directory holding the data.
file_dir = 'C://Users/maghs/Git/Movies-ETL/Data'

# %% [markdown]
# ## Wikipedia Data on Movies 1990 - 2018

# %%
# Open a file in directory using f-string inseated of typing the whole directory every time, update file_dir.
# f'{file_dir}/filename'

# Load the raw JSON into a list of dictionaries.
with open(f'{file_dir}/wikipedia-movies.json', mode='r') as file:
    wiki_movies_raw = json.load(file)

# %%
# Check how many records were loaded from JSON.
len(wiki_movies_raw)
# Out:
# 7311

# %%
# First 5 records.
wiki_movies_raw[:5]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/The_Adventures_of_Ford_Fairlane',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098987/',
#   'title': 'The Adventures of Ford Fairlane',
#   'Directed by': 'Renny Harlin',
#   'Produced by': ['Steve Perry', 'Joel Silver'],
#   'Screenplay by': ['David Arnott', 'James Cappe', 'Daniel Waters'],
#   'Story by': ['David Arnott', 'James Cappe'],
#   'Based on': ['Characters', 'by Rex Weiner'],
#   'Starring': ['Andrew Dice Clay',
#    'Wayne Newton',
#    'Priscilla Presley',
#    'Lauren Holly',
#    'Morris Day',
#    'Robert Englund',
#    "Ed O'Neill"],
#   'Narrated by': 'Andrew "Dice" Clay',
#   'Music by': ['Cliff Eidelman', 'Yello'],
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Michael Tronick',
#   'Productioncompany ': 'Silver Pictures',
#   'Distributed by': '20th Century Fox',
#   'Release date': ['July 11, 1990', '(', '1990-07-11', ')'],
#   'Running time': '102 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$21.4 million'},
#  {'url': 'https://en.wikipedia.org/wiki/After_Dark,_My_Sweet',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098994/',
#   'title': 'After Dark, My Sweet',
#   'Directed by': 'James Foley',
#   'Produced by': ['Ric Kidney', 'Robert Redlin'],
#   'Screenplay by': ['James Foley', 'Robert Redlin'],
#   'Based on': ['the novel', 'After Dark, My Sweet', 'by', 'Jim Thompson'],
#   'Starring': ['Jason Patric',
#    'Rachel Ward',
#    'Bruce Dern',
#    'George Dickerson'],
#   'Music by': 'Maurice Jarre',
#   'Cinematography': 'Mark Plummer',
#   'Edited by': 'Howard E. Smith',
#   'Productioncompany ': 'Avenue Pictures',
#   'Distributed by': 'Avenue Pictures',
#   'Release date': ['May 17, 1990',
#    '(',
#    '1990-05-17',
#    ')',
#    '(Cannes Film Market)',
#    'August 24, 1990',
#    '(',
#    '1990-08-24',
#    ')',
#    '(United States)'],
#   'Running time': '114 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$6 million',
#   'Box office': '$2.7 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Air_America_(film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099005/',
#   'title': 'Air America',
#   'Directed by': 'Roger Spottiswoode',
#   'Produced by': 'Daniel Melnick',
#   'Screenplay by': ['John Eskow', 'Richard Rush'],
#   'Based on': ['Air America', 'by', 'Christopher Robbins'],
#   'Starring': ['Mel Gibson',
#    'Robert Downey Jr.',
#    'Nancy Travis',
#    'David Marshall Grant',
#    'Lane Smith'],
#   'Music by': 'Charles Gross',
#   'Cinematography': 'Roger Deakins',
#   'Edited by': ['John Bloom', 'Lois Freeman-Fox'],
#   'Productioncompany ': ['Carolco Pictures', 'IndieProd Company'],
#   'Distributed by': 'TriStar Pictures',
#   'Release date': ['August 10, 1990', '(', '1990-08-10', ')'],
#   'Running time': '113 minutes',
#   'Country': 'United States',
#   'Language': ['English', 'Lao'],
#   'Budget': '$35 million',
#   'Box office': '$57,718,089'},
#  {'url': 'https://en.wikipedia.org/wiki/Alice_(1990_film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099012/',
#   'title': 'Alice',
#   'Directed by': 'Woody Allen',
#   'Produced by': 'Robert Greenhut',
#   'Written by': 'Woody Allen',
#   'Starring': ['Alec Baldwin',
#    'Blythe Danner',
#    'Judy Davis',
#    'Mia Farrow',
#    'William Hurt',
#    'Keye Luke',
#    'Joe Mantegna',
#    'Bernadette Peters'],
#   'Cinematography': 'Carlo Di Palma',
#   'Edited by': 'Susan E. Morse',
#   'Distributed by': 'Orion Pictures',
#   'Release date': ['December 25, 1990', '(', '1990-12-25', ')'],
#   'Running time': '106 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$12 million',
#   'Box office': '$7,331,647'},
#  {'url': 'https://en.wikipedia.org/wiki/Almost_an_Angel',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099018/',
#   'title': 'Almost an Angel',
#   'Directed by': 'John Cornell',
#   'Produced by': 'John Cornell',
#   'Written by': 'Paul Hogan',
#   'Starring': ['Paul Hogan', 'Elias Koteas', 'Linda Kozlowski'],
#   'Music by': 'Maurice Jarre',
#   'Cinematography': 'Russell Boyd',
#   'Edited by': 'David Stiven',
#   'Distributed by': 'Paramount Pictures',
#   'Release date': 'December 19, 1990',
#   'Running time': '95 minutes',
#   'Country': 'US',
#   'Language': 'English',
#   'Budget': '$25 million',
#   'Box office': '$6,939,946 (USA)'}]

# %%
# Last 5 records. 
wiki_movies_raw[-5:]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Holmes_%26_Watson',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt1255919/',
#   'title': 'Holmes & Watson',
#   'Directed by': 'Etan Cohen',
#   'Produced by': ['Will Ferrell',
#    'Adam McKay',
#    'Jimmy Miller',
#    'Clayton Townsend'],
#   'Screenplay by': 'Etan Cohen',
#   'Based on': ['Sherlock Holmes',
#    'and',
#    'Dr. Watson',
#    'by',
#    'Sir Arthur Conan Doyle'],
#   'Starring': ['Will Ferrell',
#    'John C. Reilly',
#    'Rebecca Hall',
#    'Rob Brydon',
#    'Steve Coogan',
#    'Ralph Fiennes'],
#   'Music by': 'Mark Mothersbaugh',
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Dean Zimmerman',
#   'Productioncompanies ': ['Columbia Pictures',
#    'Gary Sanchez Productions',
#    'Mosaic Media Group',
#    'Mimran Schur Pictures'],
#   'Distributed by': 'Sony Pictures Releasing',
#   'Release date': ['December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '90 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$42 million',
#   'Box office': '$41.9 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Vice_(2018_film)',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt6266538/',
#   'title': 'Vice',
#   'Directed by': 'Adam McKay',
#   'Produced by': ['Brad Pitt',
#    'Dede Gardner',
#    'Jeremy Kleiner',
#    'Kevin J. Messick',
#    'Will Ferrell',
#    'Adam McKay'],
#   'Written by': 'Adam McKay',
#   'Starring': ['Christian Bale',
#    'Amy Adams',
#    'Steve Carell',
#    'Sam Rockwell',
#    'Tyler Perry',
#    'Alison Pill',
#    'Lily Rabe',
#    'Jesse Plemons'],
#   'Music by': 'Nicholas Britell',
#   'Cinematography': 'Greig Fraser',
#   'Edited by': 'Hank Corwin',
#   'Productioncompany ': ['Plan B Entertainment',
#    'Gary Sanchez Productions',
#    'Annapurna Pictures'],
#   'Distributed by': 'Mirror Releasing',
#   'Release date': ['December 11, 2018',
#    '(',
#    '2018-12-11',
#    ')',
#    '(',
#    'Samuel Goldwyn Theater',
#    ')',
#    'December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '132 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$60 million',
#   'Box office': '$76.1 million'},
#  {'url': 'https://en.wikipedia.org/wiki/On_the_Basis_of_Sex',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt4669788/',
#   'title': 'On the Basis of Sex',
#   'Directed by': 'Mimi Leder',
#   'Produced by': 'Robert W. Cort',
#   'Written by': 'Daniel Stiepleman',
#   'Starring': ['Felicity Jones',
#    'Armie Hammer',
#    'Justin Theroux',
#    'Sam Waterston',
#    'Kathy Bates'],
#   'Music by': 'Mychael Danna',
#   'Cinematography': 'Michael Grady',
#   'Edited by': 'Michelle Tesoro',
#   'Productioncompanies ': ['Focus Features',
#    '[1]',
#    'Participant Media',
#    '[1]',
#    'Robert Cort Productions',
#    '[1]',
#    'Alibaba Pictures',
#    '[2]'],
#   'Distributed by': 'Focus Features',
#   'Release date': ['November 8, 2018',
#    '(',
#    '2018-11-08',
#    ')',
#    '(',
#    'AFI Fest',
#    ')',
#    'December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '120 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$38.4 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Destroyer_(2018_film)',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt7137380/',
#   'title': 'Destroyer',
#   'Directed by': 'Karyn Kusama',
#   'Produced by': ['Fred Berger', 'Phil Hay', 'Matt Manfredi'],
#   'Written by': ['Phil Hay', 'Matt Manfredi'],
#   'Starring': ['Nicole Kidman',
#    'Sebastian Stan',
#    'Toby Kebbell',
#    'Tatiana Maslany',
#    'Bradley Whitford',
#    'Jade Pettyjohn',
#    'Scoot McNairy'],
#   'Music by': 'Theodore Shapiro',
#   'Cinematography': 'Julie Kirkwood',
#   'Edited by': 'Plummy Tucker',
#   'Productioncompany ': ['30West',
#    'Automatik Entertainment',
#    'Annapurna Pictures'],
#   'Distributed by': 'Mirror Releasing',
#   'Release date': ['August 31, 2018',
#    '(',
#    '2018-08-31',
#    ')',
#    '(',
#    'Telluride',
#    ')',
#    'December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '123 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$9 million',
#   'Box office': '$5.5 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Black_Mirror:_Bandersnatch',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt9495224/',
#   'title': 'Bandersnatch',
#   'Directed by': 'David Slade',
#   'Produced by': 'Russell McLean',
#   'Written by': 'Charlie Brooker',
#   'Starring': ['Fionn Whitehead',
#    'Will Poulter',
#    'Craig Parkinson',
#    'Alice Lowe',
#    'Asim Chaudhry'],
#   'Music by': 'Brian Reitzell',
#   'Cinematography': ['Aaron Morton', 'Jake Polonsky'],
#   'Edited by': 'Tony Kearns',
#   'Productioncompany ': ['House of Tomorrow', 'Netflix'],
#   'Distributed by': 'Netflix',
#   'Release date': ['28 December 2018', '(', '2018-12-28', ')'],
#   'Running time': 'Variable; 90 minutes for default path',
#   'Country': 'United Kingdom',
#   'Language': 'English'}]

# %%
# Check some records in the middle.
wiki_movies_raw[3600:3605]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Benji:_Off_the_Leash!',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315273/',
#   'title': 'Benji: Off the Leash!',
#   'Directed by': 'Joe Camp',
#   'Written by': 'Joe Camp',
#   'Starring': ['Benji', 'Nick Whitaker', 'Shaggy', 'Gypsy the Cockatoo'],
#   'Music by': 'Antonio di Lorenzo',
#   'Productioncompany ': 'Mulberry Square Productions',
#   'Distributed by': 'Mulberry Square Productions',
#   'Release date': ['March 26, 2004', '(', '2004-03-26', ')'],
#   'Running time': '97 min',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$3,817,362'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Best_Thief_in_the_World',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0389796/',
#   'title': 'The Best Thief in the World',
#   'Directed by': 'Jacob Kornbluth',
#   'Produced by': ['Tim Perrell', 'Nicola Usborne'],
#   'Written by': 'Jacob Kornbluth',
#   'Starring': ['Marc Rozendaal',
#    'Michael Silverman',
#    'David Warshofsky',
#    'Audra McDonald',
#    'Lois Smith'],
#   'Music by': ['Prince Paul', 'and', 'Don Newkirk'],
#   'Cinematography': 'Ben Kutchins',
#   'Edited by': 'Stephanie Sterner',
#   'Distributed by': 'Showtime Networks',
#   'Release date': ['January 16, 2004', '(', '2004-01-16', ')'],
#   'Running time': '93 minutes',
#   'Country': 'United States',
#   'Language': 'English'},
#  {'url': 'https://en.wikipedia.org/wiki/Beyond_the_Sea_(2004_film)',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0363473/',
#   'title': 'Beyond the Sea',
#   'Directed by': 'Kevin Spacey',
#   'Produced by': ['Kevin Spacey',
#    'Phillip Barry',
#    'Dana Brunetti',
#    'Arthur Friedman',
#    'Jan Fantl',
#    'Andy Paterson'],
#   'Written by': ['Lewis Colick', 'Kevin Spacey'],
#   'Starring': ['Kevin Spacey', 'Kate Bosworth', 'Bob Hoskins', 'John Goodman'],
#   'Music by': 'Bobby Darin',
#   'Cinematography': 'Eduardo Serra',
#   'Edited by': 'Trevor Waite',
#   'Productioncompany ': 'Trigger Street Productions',
#   'Distributed by': ['Lionsgate Films',
#    '(USA)',
#    'Entertainment Film Distributors',
#    '(UK)',
#    'GAGA',
#    '(Japan)',
#    'Maple Pictures',
#    '(Canada)'],
#   'Release date': ['December 17, 2004', '(', '2004-12-17', ')'],
#   'Running time': '118 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$25 million',
#   'Box office': '$8.4 million'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Big_Bounce_(2004_film)',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315824/',
#   'title': 'The Big Bounce',
#   'Directed by': 'George Armitage',
#   'Produced by': ['George Armitage', 'Steve Bing'],
#   'Screenplay by': 'Sebastian Gutierrez',
#   'Based on': ['The Big Bounce', 'by', 'Elmore Leonard'],
#   'Starring': ['Owen Wilson',
#    'Charlie Sheen',
#    'Morgan Freeman',
#    'Sara Foster',
#    'Gary Sinise'],
#   'Music by': 'George S. Clinton',
#   'Cinematography': 'Jeffrey L. Kimball',
#   'Edited by': 'Barry Malkin',
#   'Productioncompany ': 'Shangri-La Entertainment',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Release date': ['January 30, 2004', '(', '2004-01-30', ')'],
#   'Running time': '88 minutes',
#   'Language': 'English',
#   'Budget': '$50 million',
#   'Box office': '$6.8 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Birth_(film)',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0337876/',
#   'title': 'Birth',
#   'Directed by': 'Jonathan Glazer',
#   'Produced by': ['Lizie Gower', 'Nick Morris', 'Jean-Louis Piel'],
#   'Written by': ['Jean-Claude Carrière', 'Milo Addica', 'Jonathan Glazer'],
#   'Starring': ['Nicole Kidman',
#    'Cameron Bright',
#    'Danny Huston',
#    'Lauren Bacall'],
#   'Music by': 'Alexandre Desplat',
#   'Cinematography': 'Harris Savides',
#   'Edited by': ['Sam Sneade', 'Claus Wehlisch'],
#   'Distributed by': 'New Line Cinema',
#   'Release date': ['November 8, 2004', '(', '2004-11-08', ')'],
#   'Running time': '96 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$23.9 million'}]

# %% [markdown]
# ## MovieLens Ratings & Metadata

# %%
# Read the Kaggle CSV data.
kaggle_metadata = pd.read_csv(f'{file_dir}/movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}/ratings.csv')

# %%
kaggle_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
kaggle_metadata.tail()
# Out:
#        adult belongs_to_collection budget  \
# 45461  False                   NaN      0
# 45462  False                   NaN      0
# 45463  False                   NaN      0
# 45464  False                   NaN      0
# 45465  False                   NaN      0
#
#                                                   genres  \
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language       original_title  \
# 45461                fa              رگ خواب
# 45462                tl  Siglo ng Pagluluwal
# 45463                en             Betrayal
# 45464                en  Satana likuyushchiy
# 45465                en             Queerama
#
#                                                 overview  ... release_date  \
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#       revenue runtime                          spoken_languages    status  \
# 45461     0.0    90.0    [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462     0.0   360.0         [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463     0.0    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464     0.0    87.0                                        []  Released
# 45465     0.0    75.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                           tagline                title  video  \
# 45461  Rising and falling between a man and woman               Subdue  False
# 45462                                         NaN  Century of Birthing  False
# 45463                      A deadly game of wits.             Betrayal  False
# 45464                                         NaN     Satan Triumphant  False
# 45465                                         NaN             Queerama  False
#
#       vote_average vote_count
# 45461          4.0        1.0
# 45462          9.0        3.0
# 45463          3.8        6.0
# 45464          0.0        0.0
# 45465          0.0        0.0
#
# [5 rows x 24 columns]

# %%
kaggle_metadata.sample(5)
# Out:
#        adult                              belongs_to_collection    budget  \
# 5060   False                                                NaN         0
# 32079  False  {'id': 41083, 'name': 'Scuola di ladri - Colle...         0
# 4804   False  {'id': 284024, 'name': 'The Exterminator Colle...         0
# 161    False                                                NaN  27000000
# 41992  False                                                NaN         0
#
#                                                   genres homepage      id  \
# 5060   [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN   15310
# 32079                                                 []      NaN   38313
# 4804   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...      NaN   37835
# 161    [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...      NaN    8512
# 41992                     [{'id': 35, 'name': 'Comedy'}]      NaN  365037
#
#          imdb_id original_language         original_title  \
# 5060   tt0080948                en        The Jazz Singer
# 32079  tt0091911                it        Scuola di ladri
# 4804   tt0080707                en       The Exterminator
# 161    tt0112857                en  Devil in a Blue Dress
# 41992  tt3599642                en          Swearnet Live
#
#                                                 overview  ... release_date  \
# 5060   Neil Diamond stars as Yussel in this tale of a...  ...   1980-12-17
# 32079  Frenetic in its pacing and with miniscule char...  ...   1986-09-25
# 4804   A man's best friend is killed on the streets o...  ...   1980-09-10
# 161    In late 1940s Los Angeles, Easy Rawlins is an ...  ...   1995-09-15
# 41992  "Trailer Park Boys" John Paul Tremblay, Robb W...  ...   2014-10-01
#
#           revenue runtime                           spoken_languages  \
# 5060          0.0   115.0   [{'iso_639_1': 'en', 'name': 'English'}]
# 32079         0.0    96.0  [{'iso_639_1': 'it', 'name': 'Italiano'}]
# 4804          0.0   101.0   [{'iso_639_1': 'en', 'name': 'English'}]
# 161    16140822.0   102.0   [{'iso_639_1': 'en', 'name': 'English'}]
# 41992         0.0    75.0   [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 5060   Released  His story will make you cry. His music will ma...
# 32079  Released                                                NaN
# 4804   Released  A one man army. A new kind of soldier in a new...
# 161    Released  Private detective Easy Rawlins has been caught...
# 41992  Released                                                NaN
#
#                        title  video vote_average vote_count
# 5060         The Jazz Singer  False          5.9       10.0
# 32079      School of Thieves  False          5.9       51.0
# 4804        The Exterminator  False          6.1       35.0
# 161    Devil in a Blue Dress  False          6.3       88.0
# 41992          Swearnet Live  False          6.0        2.0
#
# [5 rows x 24 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ratings.tail()
# Out:
#           userId  movieId  rating   timestamp
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 6471348    66780     2571     5.0  1457649211
# 6757923    69741     2115     3.5  1391135949
# 10600535  109389     3969     3.5  1119187713
# 22179435  230241     8464     4.0  1134416243
# 7891825    81353     3910     3.5  1201099232

# %% [markdown]
# ## Investigate the Wikipedia Data

# %%
# Turn the raw wiki data into a DataFrame.
wiki_movies_df = pd.DataFrame(wiki_movies_raw)
wiki_movies_df.head()
# Out:
#                                                  url    year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# 2  Roger Spottiswoode               Daniel Melnick
# 3         Woody Allen              Robert Greenhut
# 4        John Cornell                 John Cornell
#
#                                 Screenplay by                     Story by  \
# 0  [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                [James Foley, Robert Redlin]                          NaN
# 2                  [John Eskow, Richard Rush]                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  ... Predecessor  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...         NaN
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...  ...         NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...         NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...         NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...         NaN
#
#   Founders Area served Products Services Russian Hebrew Revenue  \
# 0      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 1      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 2      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 3      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 4      NaN         NaN      NaN      NaN     NaN    NaN     NaN
#
#   Operating income Polish
# 0              NaN    NaN
# 1              NaN    NaN
# 2              NaN    NaN
# 3              NaN    NaN
# 4              NaN    NaN
#
# [5 rows x 193 columns]

# %%
# Get the columns of the wiki data by turning them into a list (too many columns to print)
wiki_movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Author',
#  'Publisher',
#  'Publication date',
#  'Media type',
#  'Pages',
#  'ISBN',
#  'OCLC',
#  'LC Class',
#  'Cover artist',
#  'Series',
#  'Set in',
#  'Adaptation by',
#  'Suggested by',
#  'Biographical data',
#  'Born',
#  'Died',
#  'Resting place',
#  'Occupation',
#  'Years active',
#  'Spouse(s)',
#  'Children',
#  'Parent(s)',
#  'Genres',
#  'Instruments',
#  'Labels',
#  'Website',
#  'Traditional',
#  'Mandarin',
#  'Type',
#  'Industry',
#  'Fate',
#  'Founded',
#  'Founder',
#  'Headquarters',
#  'Parent',
#  'Released',
#  'Recorded',
#  'Venue',
#  'Length',
#  'Label',
#  'Director',
#  'Producer',
#  'Area',
#  'Coordinates',
#  'Status',
#  'Opening date',
#  'Closing date',
#  'Replaced',
#  'Replaced by',
#  'Name',
#  'Attraction type',
#  'Music',
#  'Duration',
#  'Simplified Chinese',
#  'Traditional Chinese',
#  'Hanyu Pinyin',
#  'Literal meaning',
#  'Transcriptions',
#  'Bopomofo',
#  'Gwoyeu Romatzyh',
#  'Wade–Giles',
#  'IPA',
#  'Yale Romanization',
#  'Jyutping',
#  'Hokkien POJ',
#  'Animation by',
#  'Color process',
#  'Engine(s)',
#  'Genre(s)',
#  'Actor control',
#  'Production company',
#  'Release(s)',
#  'Format(s)',
#  'Simplified',
#  'Characters',
#  'Date premiered',
#  'Place premiered',
#  'Setting',
#  'Original language',
#  'Subject',
#  'Published',
#  'Dewey Decimal',
#  'Text',
#  'Illustrator',
#  'Original title',
#  'Published in English',
#  'French',
#  'Developed by',
#  'Ending theme',
#  'No. of seasons',
#  'Nationality',
#  'Portrayed by',
#  'Alias',
#  'Species',
#  'Gender',
#  'Family',
#  'Alma mater',
#  'Camera setup',
#  'Novel(s)',
#  'Comics',
#  'Film(s)',
#  'Screen story by',
#  'Hangul',
#  'Revised Romanization',
#  'McCune–Reischauer',
#  'Developer(s)',
#  'Publisher(s)',
#  'Designer(s)',
#  'Programmer(s)',
#  'Artist(s)',
#  'Writer(s)',
#  'Engine',
#  'Platform(s)',
#  'Release',
#  'Mode(s)',
#  'Original work',
#  'Television series',
#  'Japanese',
#  'Hepburn',
#  'Literally',
#  'Cantonese',
#  'Full name',
#  'Height',
#  'Seasons',
#  'Chinese',
#  'Other names',
#  'Relatives',
#  'Yiddish',
#  'Formerly',
#  'Key people',
#  'Total assets',
#  'Owner',
#  'Number of employees',
#  'Divisions',
#  'Subsidiaries',
#  'Arabic',
#  'Romanized',
#  'Predecessor',
#  'Founders',
#  'Area served',
#  'Products',
#  'Services',
#  'Russian',
#  'Hebrew',
#  'Revenue',
#  'Operating income',
#  'Polish']

# %%
# Filter(1) the data to movies with a director and an IMDB link only, using list comprehenstion.
wiki_movies = [movie for movie in wiki_movies_raw
              if ('Director' in movie or 'Directed by' in movie)
                  and 'imdb_link' in movie]
len(wiki_movies)
# Out:
# 7080

# %%
# Create a DataFrame from the filtered(1) list.
wiki_movies_df = pd.DataFrame(wiki_movies)
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# 2  Roger Spottiswoode               Daniel Melnick
# 3         Woody Allen              Robert Greenhut
# 4        John Cornell                 John Cornell
#
#                                 Screenplay by                     Story by  \
# 0  [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                [James Foley, Robert Redlin]                          NaN
# 2                  [John Eskow, Richard Rush]                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  ... Hepburn Literally  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...     NaN       NaN
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...  ...     NaN       NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...     NaN       NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...     NaN       NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...     NaN       NaN
#
#   Cantonese Chinese Yiddish Arabic Romanized Russian Hebrew Polish
# 0       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 1       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 2       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 3       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 4       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
#
# [5 rows x 78 columns]

# %%
# Get the columns in the filtered(1) DF.
wiki_movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Adaptation by',
#  'Suggested by',
#  'Traditional',
#  'Mandarin',
#  'Released',
#  'Recorded',
#  'Venue',
#  'Length',
#  'Label',
#  'Director',
#  'Producer',
#  'Animation by',
#  'Color process',
#  'Simplified',
#  'French',
#  'Camera setup',
#  'Screen story by',
#  'Hangul',
#  'Revised Romanization',
#  'McCune–Reischauer',
#  'Original title',
#  'Japanese',
#  'Hepburn',
#  'Literally',
#  'Cantonese',
#  'Chinese',
#  'Yiddish',
#  'Arabic',
#  'Romanized',
#  'Russian',
#  'Hebrew',
#  'Polish']

# %%
# second cycle is to clear no. of episode column that belong to TV shows, or add the filter(2) to the first filter code block.
wiki_movies = [movie for movie in wiki_movies_raw
              if ('Director' in movie or 'Directed by' in movie)
                  and 'imdb_link' in movie
                  and 'No. of episodes' not in movie]
len(wiki_movies)
# Out:
# 7076

# %%
# Recreate a DataFrame from the filtered(2) list.
wiki_movies_df = pd.DataFrame(wiki_movies)
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# 2  Roger Spottiswoode               Daniel Melnick
# 3         Woody Allen              Robert Greenhut
# 4        John Cornell                 John Cornell
#
#                                 Screenplay by                     Story by  \
# 0  [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                [James Foley, Robert Redlin]                          NaN
# 2                  [John Eskow, Richard Rush]                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  ... Hepburn Literally  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...     NaN       NaN
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...  ...     NaN       NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...     NaN       NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...     NaN       NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...     NaN       NaN
#
#   Cantonese Chinese Yiddish Arabic Romanized Russian Hebrew Polish
# 0       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 1       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 2       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 3       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 4       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
#
# [5 rows x 75 columns]

# %%
# Get the columns in the filtered(2) DF.
wiki_movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Preceded by',
#  'Adaptation by',
#  'Suggested by',
#  'Traditional',
#  'Mandarin',
#  'Released',
#  'Recorded',
#  'Venue',
#  'Length',
#  'Label',
#  'Director',
#  'Producer',
#  'Also known as',
#  'Animation by',
#  'Color process',
#  'Simplified',
#  'French',
#  'Screen story by',
#  'Hangul',
#  'Revised Romanization',
#  'McCune–Reischauer',
#  'Original title',
#  'Japanese',
#  'Hepburn',
#  'Literally',
#  'Cantonese',
#  'Chinese',
#  'Yiddish',
#  'Arabic',
#  'Romanized',
#  'Russian',
#  'Hebrew',
#  'Polish']

# %%
# # Create a function to clean each entry
# def clean_movie(movie):
#     movie = dict(movie) # Create a non-destructive copy
#     return movie

# %%
wiki_movies_df[wiki_movies_df['Arabic'].notnull()]
# Out:
#                                                   url  year  \
# 6834  https://en.wikipedia.org/wiki/The_Insult_(film)  2018
# 7058   https://en.wikipedia.org/wiki/Capernaum_(film)  2018
#
#                                   imdb_link       title    Directed by  \
# 6834  https://www.imdb.com/title/tt7048622/  The Insult   Ziad Doueiri
# 7058  https://www.imdb.com/title/tt8267604/   Capernaum  Nadine Labaki
#
#                                             Produced by  \
# 6834  [Rachid Bouchareb, Jean Bréhat, Julie Gayet, A...
# 7058                    [Michel Merkt, Khaled Mouzanar]
#
#                                           Screenplay by  \
# 6834                                                NaN
# 7058  [Nadine Labaki, Jihad Hojaily, Michelle Keserw...
#
#                                                Story by Based on  \
# 6834                                                NaN      NaN
# 7058  [Georges Khabbaz, Nadine Labaki, Michelle Kese...      NaN
#
#                                                Starring  ... Hepburn  \
# 6834                       [Adel Karam, Kamel El Basha]  ...     NaN
# 7058  [Zain Al Rafeea, Yordanos Shiferaw, Boluwatife...  ...     NaN
#
#         Literally Cantonese Chinese Yiddish       Arabic        Romanized  \
# 6834  Case No. 23       NaN     NaN     NaN  قضية رقم ٢٣  Qadiyya raqm 23
# 7058          NaN       NaN     NaN     NaN    کفرناحوم‎              NaN
#
#      Russian Hebrew Polish
# 6834     NaN    NaN    NaN
# 7058     NaN    NaN    NaN
#
# [2 rows x 75 columns]

# %%
wiki_movies_df[wiki_movies_df['Arabic'].notnull()]['url']
# Out:
# 6834    https://en.wikipedia.org/wiki/The_Insult_(film)
# 7058     https://en.wikipedia.org/wiki/Capernaum_(film)
# Name: url, dtype: object

# %%
# Sort columns in alphabetical order to understand what they contain.
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Also known as',
#  'Animation by',
#  'Arabic',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cantonese',
#  'Chinese',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'French',
#  'Genre',
#  'Hangul',
#  'Hebrew',
#  'Hepburn',
#  'Japanese',
#  'Label',
#  'Language',
#  'Length',
#  'Literally',
#  'Mandarin',
#  'McCune–Reischauer',
#  'Music by',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Original title',
#  'Picture format',
#  'Polish',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Recorded',
#  'Release date',
#  'Released',
#  'Revised Romanization',
#  'Romanized',
#  'Running time',
#  'Russian',
#  'Screen story by',
#  'Screenplay by',
#  'Simplified',
#  'Starring',
#  'Story by',
#  'Suggested by',
#  'Theme music composer',
#  'Traditional',
#  'Venue',
#  'Voices of',
#  'Written by',
#  'Yiddish',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
# review columns to understand the type of content in them.
wiki_movies_df[wiki_movies_df['title'] == 'The Insult']
# Out:
#                                                   url  year  \
# 6834  https://en.wikipedia.org/wiki/The_Insult_(film)  2018
#
#                                   imdb_link       title   Directed by  \
# 6834  https://www.imdb.com/title/tt7048622/  The Insult  Ziad Doueiri
#
#                                             Produced by Screenplay by  \
# 6834  [Rachid Bouchareb, Jean Bréhat, Julie Gayet, A...           NaN
#
#      Story by Based on                      Starring  ... Hepburn  \
# 6834      NaN      NaN  [Adel Karam, Kamel El Basha]  ...     NaN
#
#         Literally Cantonese Chinese Yiddish       Arabic        Romanized  \
# 6834  Case No. 23       NaN     NaN     NaN  قضية رقم ٢٣  Qadiyya raqm 23
#
#      Russian Hebrew Polish
# 6834     NaN    NaN    NaN
#
# [1 rows x 75 columns]

# %%
# review columns as a dictionary to understand the type of content in them.(easier to read)
wiki_movies_df.loc[wiki_movies_df['title'] == 'The Insult'].to_dict()
# Out:
# {'url': {6834: 'https://en.wikipedia.org/wiki/The_Insult_(film)'},
#  'year': {6834: 2018},
#  'imdb_link': {6834: 'https://www.imdb.com/title/tt7048622/'},
#  'title': {6834: 'The Insult'},
#  'Directed by': {6834: 'Ziad Doueiri'},
#  'Produced by': {6834: ['Rachid Bouchareb',
#    'Jean Bréhat',
#    'Julie Gayet',
#    'Antoun Sehnaoui',
#    'Nadia Turincev']},
#  'Screenplay by': {6834: nan},
#  'Story by': {6834: nan},
#  'Based on': {6834: nan},
#  'Starring': {6834: ['Adel Karam', 'Kamel El Basha']},
#  'Narrated by': {6834: nan},
#  'Music by': {6834: 'Éric Neveux'},
#  'Cinematography': {6834: 'Tommaso Fiorilli'},
#  'Edited by': {6834: 'Dominique Marcombe'},
#  'Productioncompany ': {6834: ['Ezekiel Films',
#    'Tessalit Productions',
#    'Rouge International']},
#  'Distributed by': {6834: ['Diaphana Films',
#    '(France)',
#    'Italia Film',
#    '(Lebanon']},
#  'Release date': {6834: ['31 August 2017',
#    '(',
#    '2017-08-31',
#    ')',
#    '(',
#    'Venice',
#    ')',
#    '14 September 2017',
#    '(',
#    '2017-09-14',
#    ')',
#    '(Lebanon)',
#    '31 January 2018',
#    '(',
#    '2018-01-31',
#    ')',
#    '(France)']},
#  'Running time': {6834: '112 minutes'},
#  'Country': {6834: ['France', 'Lebanon']},
#  'Language': {6834: 'Lebanese Arabic'},
#  'Budget': {6834: nan},
#  'Box office': {6834: '$1.6 million'},
#  'Written by': {6834: ['Ziad Doueiri', 'Joelle Touma']},
#  'Genre': {6834: nan},
#  'Theme music composer': {6834: nan},
#  'Country of origin': {6834: nan},
#  'Original language(s)': {6834: nan},
#  'Producer(s)': {6834: nan},
#  'Editor(s)': {6834: nan},
#  'Production company(s)': {6834: nan},
#  'Original network': {6834: nan},
#  'Original release': {6834: nan},
#  'Productioncompanies ': {6834: nan},
#  'Executive producer(s)': {6834: nan},
#  'Production location(s)': {6834: nan},
#  'Distributor': {6834: nan},
#  'Picture format': {6834: nan},
#  'Audio format': {6834: nan},
#  'Voices of': {6834: nan},
#  'Followed by': {6834: nan},
#  'Composer(s)': {6834: nan},
#  'Created by': {6834: nan},
#  'Preceded by': {6834: nan},
#  'Adaptation by': {6834: nan},
#  'Suggested by': {6834: nan},
#  'Traditional': {6834: nan},
#  'Mandarin': {6834: nan},
#  'Released': {6834: nan},
#  'Recorded': {6834: nan},
#  'Venue': {6834: nan},
#  'Length': {6834: nan},
#  'Label': {6834: nan},
#  'Director': {6834: nan},
#  'Producer': {6834: nan},
#  'Also known as': {6834: nan},
#  'Animation by': {6834: nan},
#  'Color process': {6834: nan},
#  'Simplified': {6834: nan},
#  'French': {6834: nan},
#  'Screen story by': {6834: nan},
#  'Hangul': {6834: nan},
#  'Revised Romanization': {6834: nan},
#  'McCune–Reischauer': {6834: nan},
#  'Original title': {6834: nan},
#  'Japanese': {6834: nan},
#  'Hepburn': {6834: nan},
#  'Literally': {6834: 'Case No. 23'},
#  'Cantonese': {6834: nan},
#  'Chinese': {6834: nan},
#  'Yiddish': {6834: nan},
#  'Arabic': {6834: 'قضية رقم ٢٣'},
#  'Romanized': {6834: 'Qadiyya raqm 23'},
#  'Russian': {6834: nan},
#  'Hebrew': {6834: nan},
#  'Polish': {6834: nan}}

# %%
insult_alt_titles = [wiki_movies_df[wiki_movies_df['title'] == 'The Insult']['Literally'], 
              wiki_movies_df[wiki_movies_df['title'] == 'The Insult']['Arabic'],
             wiki_movies_df[wiki_movies_df['title'] == 'The Insult']['Romanized']]
insult_alt_titles
# Out:
# [6834    Case No. 23
#  Name: Literally, dtype: object,
#  6834    قضية رقم ٢٣
#  Name: Arabic, dtype: object,
#  6834    Qadiyya raqm 23
#  Name: Romanized, dtype: object]

# %%
# review columns as a dictionary to understand the type of content in them.(easier to read)
wiki_movies_df.loc[wiki_movies_df['title'] == 'Capernaum'].to_dict()
# Out:
# {'url': {7058: 'https://en.wikipedia.org/wiki/Capernaum_(film)'},
#  'year': {7058: 2018},
#  'imdb_link': {7058: 'https://www.imdb.com/title/tt8267604/'},
#  'title': {7058: 'Capernaum'},
#  'Directed by': {7058: 'Nadine Labaki'},
#  'Produced by': {7058: ['Michel Merkt', 'Khaled Mouzanar']},
#  'Screenplay by': {7058: ['Nadine Labaki',
#    'Jihad Hojaily',
#    'Michelle Keserwany']},
#  'Story by': {7058: ['Georges Khabbaz',
#    'Nadine Labaki',
#    'Michelle Keserwany',
#    'Jihad Hojaily',
#    'Khaled Mouzanar']},
#  'Based on': {7058: nan},
#  'Starring': {7058: ['Zain Al Rafeea',
#    'Yordanos Shiferaw',
#    'Boluwatife Bankole',
#    'Kawthar Al Haddad',
#    'Fadi Kamel Youssef',
#    'Nour el Husseini',
#    'Alaa Chouchnieh',
#    'Cedra Izam',
#    'Nadine Labaki',
#    'Joseph Jimbazian',
#    'Farah Hasno']},
#  'Narrated by': {7058: nan},
#  'Music by': {7058: 'Khaled Mouzanar'},
#  'Cinematography': {7058: 'Christopher Aoun'},
#  'Edited by': {7058: 'Konstantin Bock'},
#  'Productioncompany ': {7058: 'Mooz Films'},
#  'Distributed by': {7058: 'Sony Pictures Classics'},
#  'Release date': {7058: ['17 May 2018',
#    '(',
#    '2018-05-17',
#    ')',
#    '(',
#    'Cannes',
#    ')',
#    '20 September 2018',
#    '(',
#    '2018-09-20',
#    ')',
#    '(Lebanon)']},
#  'Running time': {7058: '126 minutes'},
#  'Country': {7058: 'Lebanon'},
#  'Language': {7058: ['Arabic', 'Amharic']},
#  'Budget': {7058: '$4 million'},
#  'Box office': {7058: '$68.6 million'},
#  'Written by': {7058: nan},
#  'Genre': {7058: nan},
#  'Theme music composer': {7058: nan},
#  'Country of origin': {7058: nan},
#  'Original language(s)': {7058: nan},
#  'Producer(s)': {7058: nan},
#  'Editor(s)': {7058: nan},
#  'Production company(s)': {7058: nan},
#  'Original network': {7058: nan},
#  'Original release': {7058: nan},
#  'Productioncompanies ': {7058: nan},
#  'Executive producer(s)': {7058: nan},
#  'Production location(s)': {7058: nan},
#  'Distributor': {7058: nan},
#  'Picture format': {7058: nan},
#  'Audio format': {7058: nan},
#  'Voices of': {7058: nan},
#  'Followed by': {7058: nan},
#  'Composer(s)': {7058: nan},
#  'Created by': {7058: nan},
#  'Preceded by': {7058: nan},
#  'Adaptation by': {7058: nan},
#  'Suggested by': {7058: nan},
#  'Traditional': {7058: nan},
#  'Mandarin': {7058: nan},
#  'Released': {7058: nan},
#  'Recorded': {7058: nan},
#  'Venue': {7058: nan},
#  'Length': {7058: nan},
#  'Label': {7058: nan},
#  'Director': {7058: nan},
#  'Producer': {7058: nan},
#  'Also known as': {7058: nan},
#  'Animation by': {7058: nan},
#  'Color process': {7058: nan},
#  'Simplified': {7058: nan},
#  'French': {7058: nan},
#  'Screen story by': {7058: nan},
#  'Hangul': {7058: nan},
#  'Revised Romanization': {7058: nan},
#  'McCune–Reischauer': {7058: nan},
#  'Original title': {7058: nan},
#  'Japanese': {7058: nan},
#  'Hepburn': {7058: nan},
#  'Literally': {7058: nan},
#  'Cantonese': {7058: nan},
#  'Chinese': {7058: nan},
#  'Yiddish': {7058: nan},
#  'Arabic': {7058: 'کفرناحوم\u200e'},
#  'Romanized': {7058: nan},
#  'Russian': {7058: nan},
#  'Hebrew': {7058: nan},
#  'Polish': {7058: nan}}

# %%
Capernaum_alt_titles = [wiki_movies_df[wiki_movies_df['title'] == 'Capernaum']['Literally'], 
              wiki_movies_df[wiki_movies_df['title'] == 'Capernaum']['Arabic'],
             wiki_movies_df[wiki_movies_df['title'] == 'Capernaum']['Romanized']]
Capernaum_alt_titles
# Out:
# [7058    NaN
#  Name: Literally, dtype: object,
#  7058    کفرناحوم‎
#  Name: Arabic, dtype: object,
#  7058    NaN
#  Name: Romanized, dtype: object]

# %%
# Create a function(1) to clean each entry
def clean_movie(movie):
    movie = dict(movie) # Create a non-destructive copy
    alt_titles = {} # Step 1. Make an empty dict to hold all of the alternative titles.
    
    # Combine alternate titles into one list.
    # Step 2. Loop through a list of all alternative title keys
    for key in ['Also known as', 'Arabic', 'Cantonese', 'Chinese', 'French',
                'Hangul', 'Hebrew', 'Hepburn', 'Japanese', 'Literally',
                'Mandarin', 'McCune–Reischauer','Original title', 'Polish',
                'Revised Romanization', 'Romanized', 'Russian',
                'Simplified', 'Traditional', 'Yiddish']:
        # Step 2a. Check if the current key exists in the movie object.
        if key in movie:
            # Step 2b. If so, remove the key-value pair and add to the alternative titles dictionary.
            alt_titles[key] = movie[key]
            movie.pop(key)
    # Step 3. After looping through every key, add the alternative titles dict to the movie object.
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles
        
    return movie

# %%
# Make a list of clean movies using list comprehension and the function(1).
clean_movies = [clean_movie(movie) for movie in wiki_movies]
len(clean_movies)
# Out:
# 7076

# %%
# Check the first 2 items in the movies list.
i = 0
while i < 2:
    print([i], wiki_movies[i])
    i += 1

# %%
# Check the first 2 items in the movies list.
i = 0
while i < 2:
    print([i], clean_movies[i])
    i += 1

# %%
# Check new column 'alt_titles' in the movies list. notice the 'Arabic' key-value pair within alt title.
x = 7058
print(clean_movies[x])
# Out:
# {'url': 'https://en.wikipedia.org/wiki/Capernaum_(film)', 'year': 2018, 'imdb_link': 'https://www.imdb.com/title/tt8267604/', 'title': 'Capernaum', 'Directed by': 'Nadine Labaki', 'Produced by': ['Michel Merkt', 'Khaled Mouzanar'], 'Screenplay by': ['Nadine Labaki', 'Jihad Hojaily', 'Michelle Keserwany'], 'Story by': ['Georges Khabbaz', 'Nadine Labaki', 'Michelle Keserwany', 'Jihad Hojaily', 'Khaled Mouzanar'], 'Starring': ['Zain Al Rafeea', 'Yordanos Shiferaw', 'Boluwatife Bankole', 'Kawthar Al Haddad', 'Fadi Kamel Youssef', 'Nour el Husseini', 'Alaa Chouchnieh', 'Cedra Izam', 'Nadine Labaki', 'Joseph Jimbazian', 'Farah Hasno'], 'Music by': 'Khaled Mouzanar', 'Cinematography': 'Christopher Aoun', 'Edited by': 'Konstantin Bock', 'Productioncompany ': 'Mooz Films', 'Distributed by': 'Sony Pictures Classics', 'Release date': ['17 May 2018', '(', '2018-05-17', ')', '(', 'Cannes', ')', '20 September 2018', '(', '2018-09-20', ')', '(Lebanon)'], 'Running time': '126 minutes', 'Country': 'Lebanon', 'Language': ['Arabic', 'Amharic'], 'Budget': '$4 million', 'Box office': '$68.6 million', 'alt_titles': {'Arabic': 'کفرناحوم\u200e'}}

# %%
# Set wiki_movies_df to be the DataFrame created from clean_movies. notice new column 'alt_titles'.
wiki_movies_df = pd.DataFrame(clean_movies)
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# 2  Roger Spottiswoode               Daniel Melnick
# 3         Woody Allen              Robert Greenhut
# 4        John Cornell                 John Cornell
#
#                                 Screenplay by                     Story by  \
# 0  [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                [James Foley, Robert Redlin]                          NaN
# 2                  [John Eskow, Richard Rush]                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  ... Released Recorded  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...      NaN      NaN
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...  ...      NaN      NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...      NaN      NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...      NaN      NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...      NaN      NaN
#
#   Venue Length Label Director Producer Animation by Color process  \
# 0   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 1   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 2   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 3   NaN    NaN   NaN      NaN      NaN          NaN           NaN
# 4   NaN    NaN   NaN      NaN      NaN          NaN           NaN
#
#   Screen story by
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 56 columns]

# %%
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Length',
#  'Music by',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Picture format',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Recorded',
#  'Release date',
#  'Released',
#  'Running time',
#  'Screen story by',
#  'Screenplay by',
#  'Starring',
#  'Story by',
#  'Suggested by',
#  'Theme music composer',
#  'Venue',
#  'Voices of',
#  'Written by',
#  'alt_titles',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
col = wiki_movies_df['alt_titles'].tolist()
print(col)
# Out:
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, ...

# %%
# Re-Create and expand function(2) to clean each entry.
def clean_movie(movie):
    movie = dict(movie) # Create a non-destructive copy
    alt_titles = {} # Step 1. Make an empty dict to hold all of the alternative titles.
    
    # Combine alternate titles into one list.
    # Step 2. Loop through a list of all alternative title keys
    for key in ['Also known as', 'Arabic', 'Cantonese', 'Chinese', 'French', 
                'Hangul', 'Hebrew', 'Hepburn', 'Japanese', 'Literally', 
                'Mandarin', 'McCune–Reischauer','Original title', 'Polish', 
                'Revised Romanization', 'Romanized', 'Russian', 
                'Simplified', 'Traditional', 'Yiddish']:
        # Step 2a. Check if the current key exists in the movie object.
        if key in movie:
            # Step 2b. If so, remove the key-value pair and add to the alternative titles dictionary.
            alt_titles[key] = movie[key]
            movie.pop(key)
    # Step 3. After looping through every key, add the alternative titles dict to the movie object.
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles
    
    # merge column names
    def change_column_name(old_name, new_name):
        if old_name in movie:
            movie[new_name] = movie.pop(old_name)
    change_column_name('Adaptation by', 'Writer(s)')
    change_column_name('Country of origin', 'Country')
    change_column_name('Directed by', 'Director')
    change_column_name('Distributed by', 'Distributor')
    change_column_name('Edited by', 'Editor(s)')
    change_column_name('Length', 'Running time')
    change_column_name('Original release', 'Release date')
    change_column_name('Music by', 'Composer(s)')
    change_column_name('Produced by', 'Producer(s)')
    change_column_name('Producer', 'Producer(s)')
    change_column_name('Productioncompanies ', 'Production company(s)')
    change_column_name('Productioncompany ', 'Production company(s)')
    change_column_name('Released', 'Release Date')
    change_column_name('Release Date', 'Release date')
    change_column_name('Screen story by', 'Writer(s)')
    change_column_name('Screenplay by', 'Writer(s)')
    change_column_name('Story by', 'Writer(s)')
    change_column_name('Theme music composer', 'Composer(s)')
    change_column_name('Written by', 'Writer(s)')
        
    return movie

# %%
# rerun list comprehension to clean wiki_movies and recreate wiki_movies_df.
clean_movies = [clean_movie(movie) for movie in wiki_movies]
len(clean_movies)
# Out:
# 7076

# %%
# Recreat the wiki DataFrame.
wiki_movies_df = pd.DataFrame(clean_movies)
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring         Narrated by  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  Andrew "Dice" Clay
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...                 NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...                 NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...                 NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]                 NaN
#
#    Cinematography                                       Release date  \
# 0     Oliver Wood                  [July 11, 1990, (, 1990-07-11, )]
# 1    Mark Plummer  [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...
# 2   Roger Deakins                [August 10, 1990, (, 1990-08-10, )]
# 3  Carlo Di Palma              [December 25, 1990, (, 1990-12-25, )]
# 4    Russell Boyd                                  December 19, 1990
#
#   Running time  ... Followed by Created by Preceded by Suggested by  \
# 0  102 minutes  ...         NaN        NaN         NaN          NaN
# 1  114 minutes  ...         NaN        NaN         NaN          NaN
# 2  113 minutes  ...         NaN        NaN         NaN          NaN
# 3  106 minutes  ...         NaN        NaN         NaN          NaN
# 4   95 minutes  ...         NaN        NaN         NaN          NaN
#
#   alt_titles Recorded Venue Label Animation by Color process
# 0        NaN      NaN   NaN   NaN          NaN           NaN
# 1        NaN      NaN   NaN   NaN          NaN           NaN
# 2        NaN      NaN   NaN   NaN          NaN           NaN
# 3        NaN      NaN   NaN   NaN          NaN           NaN
# 4        NaN      NaN   NaN   NaN          NaN           NaN
#
# [5 rows x 39 columns]

# %%
# Get the final (39) columns in the clean df.
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Created by',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Picture format',
#  'Preceded by',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Recorded',
#  'Release date',
#  'Running time',
#  'Starring',
#  'Suggested by',
#  'Venue',
#  'Voices of',
#  'Writer(s)',
#  'alt_titles',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %% [markdown]
# ## Remove Duplicate Rows using Regex

# %%
# Use Pandas built-in string method to extract IMDb IDs from imdb_link and put them in a new column.
wiki_movies_df['imdb_id'] = wiki_movies_df['imdb_link'].str.extract(r'(tt\d{7})')
print(len(wiki_movies_df))
print(len(wiki_movies_df['imdb_id']))
# Out:
# 7076
# 7076

# %%
# Drop duplicates of IMDb IDs using drop_duplicates() and only consider IMDb ID by using subset argument, and inplace to it's performed on the selected DF.
wiki_movies_df.drop_duplicates(subset='imdb_id', inplace=True)
# Show how many rows were dropped.
print(len(wiki_movies_df))
# Out:
# 7033

# %%
# Check DF with one added column (imdb_id) at the end. (40 columns)
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring         Narrated by  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  Andrew "Dice" Clay
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...                 NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...                 NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...                 NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]                 NaN
#
#    Cinematography                                       Release date  \
# 0     Oliver Wood                  [July 11, 1990, (, 1990-07-11, )]
# 1    Mark Plummer  [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...
# 2   Roger Deakins                [August 10, 1990, (, 1990-08-10, )]
# 3  Carlo Di Palma              [December 25, 1990, (, 1990-12-25, )]
# 4    Russell Boyd                                  December 19, 1990
#
#   Running time  ... Created by Preceded by Suggested by alt_titles Recorded  \
# 0  102 minutes  ...        NaN         NaN          NaN        NaN      NaN
# 1  114 minutes  ...        NaN         NaN          NaN        NaN      NaN
# 2  113 minutes  ...        NaN         NaN          NaN        NaN      NaN
# 3  106 minutes  ...        NaN         NaN          NaN        NaN      NaN
# 4   95 minutes  ...        NaN         NaN          NaN        NaN      NaN
#
#   Venue Label Animation by Color process    imdb_id
# 0   NaN   NaN          NaN           NaN  tt0098987
# 1   NaN   NaN          NaN           NaN  tt0098994
# 2   NaN   NaN          NaN           NaN  tt0099005
# 3   NaN   NaN          NaN           NaN  tt0099012
# 4   NaN   NaN          NaN           NaN  tt0099018
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Remove Mostly Null Columns

# %%
# Check how many null values are in each column out of 40 cols for 7,033 rows.
wiki_movies_df.isnull().sum()
# Out:
# url                          0
# year                         0
# imdb_link                    0
# title                        1
# Based on                  4852
# Starring                   184
# Narrated by               6752
# Cinematography             691
# Release date                32
# Running time               139
# Country                    236
# Language                   244
# Budget                    2295
# Box office                1548
# Director                     0
# Distributor                357
# Editor(s)                  548
# Composer(s)                518
# Producer(s)                202
# Production company(s)     1678
# Writer(s)                  199
# Genre                     6923
# Original language(s)      6875
# Original network          6908
# Executive producer(s)     6936
# Production location(s)    6986
# Picture format            6969
# Audio format              6972
# Voices of                 7031
# Followed by               7024
# Created by                7023
# Preceded by               7023
# Suggested by              7032
# alt_titles                7012
# Recorded                  7031
# Venue                     7032
# Label                     7031
# Animation by              7031
# Color process             7032
# imdb_id                      0
# dtype: int64

# %%
# another way using list comprehension: Check how many null values are in each column out of 40 cols for 7,033 rows.
[[column, wiki_movies_df[column].isnull().sum()] for column in wiki_movies_df.columns]
# Out:
# [['url', 0],
#  ['year', 0],
#  ['imdb_link', 0],
#  ['title', 1],
#  ['Based on', 4852],
#  ['Starring', 184],
#  ['Narrated by', 6752],
#  ['Cinematography', 691],
#  ['Release date', 32],
#  ['Running time', 139],
#  ['Country', 236],
#  ['Language', 244],
#  ['Budget', 2295],
#  ['Box office', 1548],
#  ['Director', 0],
#  ['Distributor', 357],
#  ['Editor(s)', 548],
#  ['Composer(s)', 518],
#  ['Producer(s)', 202],
#  ['Production company(s)', 1678],
#  ['Writer(s)', 199],
#  ['Genre', 6923],
#  ['Original language(s)', 6875],
#  ['Original network', 6908],
#  ['Executive producer(s)', 6936],
#  ['Production location(s)', 6986],
#  ['Picture format', 6969],
#  ['Audio format', 6972],
#  ['Voices of', 7031],
#  ['Followed by', 7024],
#  ['Created by', 7023],
#  ['Preceded by', 7023],
#  ['Suggested by', 7032],
#  ['alt_titles', 7012],
#  ['Recorded', 7031],
#  ['Venue', 7032],
#  ['Label', 7031],
#  ['Animation by', 7031],
#  ['Color process', 7032],
#  ['imdb_id', 0]]

# %%
# a third way is using 'for' loop and 'print' statement to find the null sum in each column.
for column in (wiki_movies_df.columns):
    print([column, wiki_movies_df[column].isnull().sum()])
# Out:
# ['url', 0]
# ['year', 0]
# ['imdb_link', 0]
# ['title', 1]
# ['Based on', 4852]
# ['Starring', 184]
# ['Narrated by', 6752]
# ['Cinematography', 691]
# ['Release date', 32]
# ['Running time', 139]
# ['Country', 236]
# ['Language', 244]
# ['Budget', 2295]
# ['Box office', 1548]
# ['Director', 0]
# ['Distributor', 357]
# ['Editor(s)', 548]
# ['Composer(s)', 518]
# ['Producer(s)', 202]
# ['Production company(s)', 1678]
# ['Writer(s)', 199]
# ['Genre', 6923]
# ['Original language(s)', 6875]
# ['Original network', 6908]
# ['Executive producer(s)', 6936]
# ['Production location(s)', 6986]
# ['Picture format', 6969]
# ['Audio format', 6972]
# ['Voices of', 7031]
# ['Followed by', 7024]
# ['Created by', 7023]
# ['Preceded by', 7023]
# ['Suggested by', 7032]
# ['alt_titles', 7012]
# ['Recorded', 7031]
# ['Venue', 7032]
# ['Label', 7031]
# ['Animation by', 7031]
# ['Color process', 7032]
# ['imdb_id', 0]

# %%
# Plan to remove the nulls by first making a list of columns with <90% nulls, by tweaking the list comprehension statement. 
wiki_columns_to_keep = [column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * 0.9]
len(wiki_columns_to_keep)
# Out:
# 21

# %%
type(wiki_columns_to_keep)
# Out:
# list

# %%
# Recreate the DF with only the columns to keep that have > 10% not null (i.e. <90% null).
wiki_movies_df = wiki_movies_df[wiki_columns_to_keep]
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  Cinematography  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...     Oliver Wood
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...    Mark Plummer
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...   Roger Deakins
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  Carlo Di Palma
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]    Russell Boyd
#
#                                         Release date Running time  \
# 0                  [July 11, 1990, (, 1990-07-11, )]  102 minutes
# 1  [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...  114 minutes
# 2                [August 10, 1990, (, 1990-08-10, )]  113 minutes
# 3              [December 25, 1990, (, 1990-12-25, )]  106 minutes
# 4                                  December 19, 1990   95 minutes
#
#          Country  ...       Budget        Box office            Director  \
# 0  United States  ...  $20 million     $21.4 million        Renny Harlin
# 1  United States  ...   $6 million      $2.7 million         James Foley
# 2  United States  ...  $35 million       $57,718,089  Roger Spottiswoode
# 3  United States  ...  $12 million        $7,331,647         Woody Allen
# 4             US  ...  $25 million  $6,939,946 (USA)        John Cornell
#
#           Distributor                       Editor(s)  \
# 0    20th Century Fox                 Michael Tronick
# 1     Avenue Pictures                 Howard E. Smith
# 2    TriStar Pictures  [John Bloom, Lois Freeman-Fox]
# 3      Orion Pictures                  Susan E. Morse
# 4  Paramount Pictures                    David Stiven
#
#                Composer(s)                  Producer(s)  \
# 0  [Cliff Eidelman, Yello]   [Steve Perry, Joel Silver]
# 1            Maurice Jarre  [Ric Kidney, Robert Redlin]
# 2            Charles Gross               Daniel Melnick
# 3                      NaN              Robert Greenhut
# 4            Maurice Jarre                 John Cornell
#
#                    Production company(s)                     Writer(s)  \
# 0                        Silver Pictures   [David Arnott, James Cappe]
# 1                        Avenue Pictures  [James Foley, Robert Redlin]
# 2  [Carolco Pictures, IndieProd Company]    [John Eskow, Richard Rush]
# 3                                    NaN                   Woody Allen
# 4                                    NaN                    Paul Hogan
#
#      imdb_id
# 0  tt0098987
# 1  tt0098994
# 2  tt0099005
# 3  tt0099012
# 4  tt0099018
#
# [5 rows x 21 columns]

# %%
# Notice the df is down to (21) columns and the 'alt_title' column is gone. 
wiki_movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Based on',
#  'Starring',
#  'Cinematography',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Composer(s)',
#  'Producer(s)',
#  'Production company(s)',
#  'Writer(s)',
#  'imdb_id']

# %%
# look for the alt_titles column in the arabic movie 'The Insult', now with a different index. 
wiki_movies_df.loc[wiki_movies_df['title'] == 'The Insult'].to_dict()
# it's gone!
# Out:
# {'url': {6834: 'https://en.wikipedia.org/wiki/The_Insult_(film)'},
#  'year': {6834: 2018},
#  'imdb_link': {6834: 'https://www.imdb.com/title/tt7048622/'},
#  'title': {6834: 'The Insult'},
#  'Based on': {6834: nan},
#  'Starring': {6834: ['Adel Karam', 'Kamel El Basha']},
#  'Cinematography': {6834: 'Tommaso Fiorilli'},
#  'Release date': {6834: ['31 August 2017',
#    '(',
#    '2017-08-31',
#    ')',
#    '(',
#    'Venice',
#    ')',
#    '14 September 2017',
#    '(',
#    '2017-09-14',
#    ')',
#    '(Lebanon)',
#    '31 January 2018',
#    '(',
#    '2018-01-31',
#    ')',
#    '(France)']},
#  'Running time': {6834: '112 minutes'},
#  'Country': {6834: ['France', 'Lebanon']},
#  'Language': {6834: 'Lebanese Arabic'},
#  'Budget': {6834: nan},
#  'Box office': {6834: '$1.6 million'},
#  'Director': {6834: 'Ziad Doueiri'},
#  'Distributor': {6834: ['Diaphana Films',
#    '(France)',
#    'Italia Film',
#    '(Lebanon']},
#  'Editor(s)': {6834: 'Dominique Marcombe'},
#  'Composer(s)': {6834: 'Éric Neveux'},
#  'Producer(s)': {6834: ['Rachid Bouchareb',
#    'Jean Bréhat',
#    'Julie Gayet',
#    'Antoun Sehnaoui',
#    'Nadia Turincev']},
#  'Production company(s)': {6834: ['Ezekiel Films',
#    'Tessalit Productions',
#    'Rouge International']},
#  'Writer(s)': {6834: ['Ziad Doueiri', 'Joelle Touma']},
#  'imdb_id': {6834: 'tt7048622'}}

# %% [markdown]
# ## Convert and Parse the Wiki Data

# %%
# Check the data types of columns in wiki dataframe.
wiki_movies_df.dtypes
# Out:
# url                      object
# year                      int64
# imdb_link                object
# title                    object
# Based on                 object
# Starring                 object
# Cinematography           object
# Release date             object
# Running time             object
# Country                  object
# Language                 object
# Budget                   object
# Box office               object
# Director                 object
# Distributor              object
# Editor(s)                object
# Composer(s)              object
# Producer(s)              object
# Production company(s)    object
# Writer(s)                object
# imdb_id                  object
# dtype: object

# %%
len(wiki_movies_df)
# Out:
# 7033

# %% [markdown]
# ### Parse the Box Office Data

# %%
# Collect the rows with box office data. it will be defined as a series. 
box_office = wiki_movies_df['Box office'].dropna()
type(box_office)

# %%
# Check the number of data points that exists in the box office series. 
len(box_office)
# Out:
# 5485

# %%
print(box_office[0:5])
# Out:
# 0       $21.4 million
# 1        $2.7 million
# 2         $57,718,089
# 3          $7,331,647
# 4    $6,939,946 (USA)
# Name: Box office, dtype: object

# %%
print(box_office.sample(n=5))
# Out:
# 3949                            $12 million
# 3070                            $51,801,187
# 7042                          $35.2 million
# 4656                           $128 million
# 1761    [$2,821,671, [, citation needed, ]]
# Name: Box office, dtype: object

# %%
# Regex only work on strings, so make sure all box office data is string. 
# 1. define a function to find the type of data in the box office series.
def is_not_a_string(x):
    return type(x) != str
# 2. use the map() function to see the values that are not strings. 
box_office[box_office.map(is_not_a_string)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 74                    [$6,488,144, (US), [1]]
# 126                [US$1,531,489, (domestic)]
# 130                          [US$, 4,803,039]
#                         ...
# 6980               [$99.6, million, [4], [5]]
# 6994                   [$365.6, million, [1]]
# 6995                         [$53.8, million]
# 7015                     [$435, million, [7]]
# 7048                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %%
# another way is to use anonymous lambda function inside map() in one code line. 
box_office[box_office.map(lambda x: type(x) != str)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 74                    [$6,488,144, (US), [1]]
# 126                [US$1,531,489, (domestic)]
# 130                          [US$, 4,803,039]
#                         ...
# 6980               [$99.6, million, [4], [5]]
# 6994                   [$365.6, million, [1]]
# 6995                         [$53.8, million]
# 7015                     [$435, million, [7]]
# 7048                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %%
# some box office data points are stored as lists, 
# use simple space as the joining character and apply join() function only when data points are lists.
box_office = box_office.apply(lambda x: ' '.join(x) if type(x) == list else x)
box_office.sample(n=5)
# Out:
# 2297                                         $5.5 million
# 3132                                        $38.3 million
# 56                                      $2.7 million (US)
# 5693                                             $408,015
# 4641    US$22,211,426 (worldwide) £1,034,659 [3] (Unit...
# Name: Box office, dtype: object

# %%
# Create the second form to match the box office data in form "$123.4 million or billion".
form_one = r"\$\d+\.?\d*\s*[mb]illion"

# %%
# Count up how many box office values match the first form, ignore upper- lowercase, parse the non-string data to False.
box_office.str.contains(form_one, flags=re.IGNORECASE, na=False).sum()
# Out:
# 3896

# %%
# Create the first form to match the box office data in form "$123,456,789"
form_two = r"\$\d{1,3}(?:,\d{3})+"

# %%
# Count up how many box office values match the second form, ignore upper- lowercase, parse the non-string data to False.
box_office.str.contains(form_two, flags=re.IGNORECASE, na=False).sum()
# Out:
# 1544

# %%
# Most of the box office values are described by either form (out of 5,485) movies.
3896+1544
# Out:
# 5440

# %%
# Create two boolean series to look for matches then use to find the values that don't match either.
matches_form_one = box_office.str.contains(form_one, flags=re.IGNORECASE, na=False)
matches_form_two = box_office.str.contains(form_two, flags=re.IGNORECASE, na=False)

# %%
# Select the box office values that don't match either forms.
box_office[(not matches_form_one) and (not matches_form_two)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20436\1066363728.py in <module>
#       1 # Select the box office values that don't match either forms.
# ----> 2 box_office[(not matches_form_one) and (not matches_form_two)]
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1536     def __nonzero__(self):
#    1537         raise ValueError(
# -> 1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1540         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Select the box office values that don't match either forms, using Pandas element-wise logical operators.
# tilde ~ (similar to 'not'), ampersand & is 'and', pipe | is 'or'.
box_office[~matches_form_one & ~matches_form_two]
# Out:
# 34                         US$ 4,212,828
# 79                              $335.000
# 110                   $4.35-4.37 million
# 130                        US$ 4,803,039
# 600                           $5000 (US)
# 731                         $ 11,146,270
# 957                             $ 50,004
# 1070                          35,254,617
# 1147    $ 407,618 (U.S.) (sub-total) [1]
# 1446                        $ 11,829,959
# 1480                          £3 million
# 1611                            $520.000
# 1865                        ¥1.1 billion
# 2032                                 N/A
# 2091                                $309
# 2130               US$ 171.8 million [9]
# 2257                   US$ 3,395,581 [1]
# 2263            $ 1,223,034 ( domestic )
# 2347                            $282.175
# 2638            $ 104,883 (US sub-total)
# 2665         926,423 admissions (France)
# 2697      $ 1.7 million (US) (sub-total)
# 2823                            $414.000
# 2924                            $621.000
# 3088           $32 [2] –33.1 million [1]
# 3631                                 TBA
# 3859                  $38.9–40.3 million
# 3879            CN¥3.650 million (China)
# 4116                          £7,385,434
# 4123                            $161.000
# 4261                  $20.7–23.9 million
# 4306                              $20-30
# 4492                        $47.7 millon
# 4561             $45.2k (only in Turkey)
# 4662                USD$ 8.2 million [2]
# 5362                   $ 142 million [3]
# 5447                               £2.56
# 5784                            413 733$
# 6013                             Unknown
# 6145                  $17.5–18.4 million
# 6234                  $41.8–41.9 million
# 6369                               $111k
# 6370                                $588
# 6593                      less than $372
# 6829                    $ 41 million [3]
# 6843                             8 crore
# 6904                         $6.9 millon
# Name: Box office, dtype: object

# %%
# 1. Fix pattern match where there's a space in between the dollar sign and the number. 
form_one = r"\$\s*\d+\.?\d*\s*[mb]illion"
form_two = r"\$\s*\d{1,3}(?:,\d{3})+"

# %%
# 2. Fix pattern match where there's a period as a thousand's separator, not a comma, but don't capture any values like 1.234 billion.
form_two = r"\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)"

# %%
# 3. Fix pattern match where the values are given as a range by replacing the hyphen after $number with only a $.
box_office = box_office.replace(r"\$.*[-—–](?![a-z])", '$', regex=True)

# %%
# 4. Fix pattern match where'Million' is sometimes misspelled as 'millon'.
form_one = r"\$\s*\d+\.?\d*\s*[mb]illi?on"

# %%
box_office[~matches_form_one & ~matches_form_two]
# Out:
# 34                         US$ 4,212,828
# 79                              $335.000
# 110                        $4.37 million
# 130                        US$ 4,803,039
# 600                           $5000 (US)
# 731                         $ 11,146,270
# 957                             $ 50,004
# 1070                          35,254,617
# 1147    $ 407,618 (U.S.) (sub-total) [1]
# 1446                        $ 11,829,959
# 1480                          £3 million
# 1611                            $520.000
# 1865                        ¥1.1 billion
# 2032                                 N/A
# 2091                                $309
# 2130               US$ 171.8 million [9]
# 2257                   US$ 3,395,581 [1]
# 2263            $ 1,223,034 ( domestic )
# 2347                            $282.175
# 2638            $ 104,883 (US sub-total)
# 2665         926,423 admissions (France)
# 2697      $ 1.7 million (US) (sub-total)
# 2823                            $414.000
# 2924                            $621.000
# 3088                   $33.1 million [1]
# 3631                                 TBA
# 3859                       $40.3 million
# 3879            CN¥3.650 million (China)
# 4116                          £7,385,434
# 4123                            $161.000
# 4261                       $23.9 million
# 4306                                 $30
# 4492                        $47.7 millon
# 4561             $45.2k (only in Turkey)
# 4662                USD$ 8.2 million [2]
# 5362                   $ 142 million [3]
# 5447                               £2.56
# 5784                            413 733$
# 6013                             Unknown
# 6145                       $18.4 million
# 6234                       $41.9 million
# 6369                               $111k
# 6370                                $588
# 6593                      less than $372
# 6829                    $ 41 million [3]
# 6843                             8 crore
# 6904                         $6.9 millon
# Name: Box office, dtype: object

# %%
# Check our work by creating two boolean series to look for matches then use to find the values that don't match either.
match_form_one = box_office.str.contains(form_one, flags=re.IGNORECASE, na=False)
match_form_two = box_office.str.contains(form_two, flags=re.IGNORECASE, na=False)
box_office[~match_form_one & ~match_form_two]
# ignore the rest for they constitute a small percentage of the data, only (19) entries.
# Out:
# 600                      $5000 (US)
# 1070                     35,254,617
# 1480                     £3 million
# 1865                   ¥1.1 billion
# 2032                            N/A
# 2091                           $309
# 2665    926,423 admissions (France)
# 3631                            TBA
# 3879       CN¥3.650 million (China)
# 4116                     £7,385,434
# 4306                            $30
# 4561        $45.2k (only in Turkey)
# 5447                          £2.56
# 5784                       413 733$
# 6013                        Unknown
# 6369                          $111k
# 6370                           $588
# 6593                 less than $372
# 6843                        8 crore
# Name: Box office, dtype: object

# %%
# Extract the box office data that matches either forms using regular expression, and convert to a DataFrame. 
box_office.str.extract(f'({form_one}|{form_two})')
# Out:
#                   0
# 0     $21.4 million
# 1      $2.7 million
# 2       $57,718,089
# 3        $7,331,647
# 4        $6,939,946
# ...             ...
# 7070  $19.4 million
# 7071  $41.9 million
# 7072  $76.1 million
# 7073  $38.4 million
# 7074   $5.5 million
#
# [5485 rows x 1 columns]

# %%
# Define a function to turn the extracted values (strings) to numberic (floating-point decimal) values. 
# Since we're working directly with strings, we'll use the re module to access the regex functions. 
# Use re.match(pattern, string) to see if our string matches a pattern. 
# Use re.sub(pattern, replacement_string, string) to remove dollar signs, spaces, commas, and letter, if necessary.
# Convert all strings to floats, multiply by the right amount, and return the value.

def parse_dollars(s):
    # if s is not a string, return NaN
    if type(s) != str:
        return np.nan
    
    # if input is of the form $###.# million
    if re.match(r'\$\s*\d+\.?\d*\s*milli?on', s, flags=re.IGNORECASE):
        
        # remove dollar sign and "million"
        s = re.sub('\$|\s|[a-zA-Z]','', s)
        
        # convert to float and multiply by a million
        value = float(s) * 10**6
        
        # return value
        return value
        
    # if input is of the form $###.# billion 
    elif re.match(r'\$\s*\d+\.?\d*\s*billi?on', s, flags=re.IGNORECASE):
    
        # remove dollar sign and "billion"
        s = re.sub('\$|\s|[a-zA-Z]','', s)
        
        # convert to float and multiply by a billion
        value = float(s) * 10**9
        
        # return value
        return value
        
    # if input is of the form $###,###,###
    elif re.match(r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)', s, flags=re.IGNORECASE):
        
        # remove dollar sign and commas
        s = re.sub('\$|,','', s)
        
        # convert to float
        value = float(s)
        
        # return value
        return value
    
    # otherwise, return NaN
    else: 
        return np.nan

# %%
# now we have all we need to parse the box office values to numeric values. 
# extract the values from box_office using str.extract. then apply the parse_dollars to the first col of DF returned by str.extract.
wiki_movies_df['box_office'] = box_office.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)

# %%
# Check the new column in the DF.
wiki_movies_df['box_office']
# Out:
# 0       21400000.0
# 1        2700000.0
# 2       57718089.0
# 3        7331647.0
# 4        6939946.0
#            ...
# 7071    41900000.0
# 7072    76100000.0
# 7073    38400000.0
# 7074     5500000.0
# 7075           NaN
# Name: box_office, Length: 7033, dtype: float64

# %%
# Drop the 'Box office' column since it's no longer needed. 
wiki_movies_df.drop('Box office', axis=1, inplace=True)

# %%
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  Cinematography  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...     Oliver Wood
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...    Mark Plummer
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...   Roger Deakins
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  Carlo Di Palma
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]    Russell Boyd
#
#                                         Release date Running time  \
# 0                  [July 11, 1990, (, 1990-07-11, )]  102 minutes
# 1  [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...  114 minutes
# 2                [August 10, 1990, (, 1990-08-10, )]  113 minutes
# 3              [December 25, 1990, (, 1990-12-25, )]  106 minutes
# 4                                  December 19, 1990   95 minutes
#
#          Country  ...       Budget            Director         Distributor  \
# 0  United States  ...  $20 million        Renny Harlin    20th Century Fox
# 1  United States  ...   $6 million         James Foley     Avenue Pictures
# 2  United States  ...  $35 million  Roger Spottiswoode    TriStar Pictures
# 3  United States  ...  $12 million         Woody Allen      Orion Pictures
# 4             US  ...  $25 million        John Cornell  Paramount Pictures
#
#                         Editor(s)              Composer(s)  \
# 0                 Michael Tronick  [Cliff Eidelman, Yello]
# 1                 Howard E. Smith            Maurice Jarre
# 2  [John Bloom, Lois Freeman-Fox]            Charles Gross
# 3                  Susan E. Morse                      NaN
# 4                    David Stiven            Maurice Jarre
#
#                    Producer(s)                  Production company(s)  \
# 0   [Steve Perry, Joel Silver]                        Silver Pictures
# 1  [Ric Kidney, Robert Redlin]                        Avenue Pictures
# 2               Daniel Melnick  [Carolco Pictures, IndieProd Company]
# 3              Robert Greenhut                                    NaN
# 4                 John Cornell                                    NaN
#
#                       Writer(s)    imdb_id  box_office
# 0   [David Arnott, James Cappe]  tt0098987  21400000.0
# 1  [James Foley, Robert Redlin]  tt0098994   2700000.0
# 2    [John Eskow, Richard Rush]  tt0099005  57718089.0
# 3                   Woody Allen  tt0099012   7331647.0
# 4                    Paul Hogan  tt0099018   6939946.0
#
# [5 rows x 21 columns]

# %%
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Based on',
#  'Budget',
#  'Cinematography',
#  'Composer(s)',
#  'Country',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Language',
#  'Producer(s)',
#  'Production company(s)',
#  'Release date',
#  'Running time',
#  'Starring',
#  'Writer(s)',
#  'box_office',
#  'imdb_id',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %% [markdown]
# ### Parse Budget Data

# %%
# Collect the rows with budget data. it will be defined as a series. 
budget = wiki_movies_df['Budget'].dropna()
type(budget)
# Out:
# pandas.core.series.Series

# %%
# Check the number of data points that exists in the budget series. 
len(budget)
# Out:
# 4738

# %%
print(budget[0:5])
# Out:
# 0    $20 million
# 1     $6 million
# 2    $35 million
# 3    $12 million
# 4    $25 million
# Name: Budget, dtype: object

# %%
print(budget.sample(n=5))
# Out:
# 3513             $40 million
# 4777             $22 million
# 1842             $32 million
# 6251    [$6.5, million, [2]]
# 6891             $21 million
# Name: Budget, dtype: object

# %%
print(budget.sample(n=10))
# Out:
# 5047         $17 million
# 4859       US$30 million
# 3000         $17 million
# 999          $60 million
# 6162         $40 million
# 4296         $80 million
# 5964         $60 million
# 4554    $70-88.5 million
# 6197         $13 million
# 5793            $250,000
# Name: Budget, dtype: object

# %%
print(budget.sample(n=10))
# Out:
# 6847                            $200 million
# 740                              $12 million
# 5777                              $8 million
# 6222    [$45 million, [, citation needed, ]]
# 1736                                $200,000
# 1226                                 Unknown
# 4695                             $62 million
# 3433                             $17 million
# 1292                             $27 million
# 3402                             $85 million
# Name: Budget, dtype: object

# %%
# after sampling the 'budget' series, we see $, lists, million, commas, other alphabetical characters.

# %%
# Regex only work on strings, so make sure all box office data is string. 
# Use the map() function to see the values that are not strings. 
# and use anonymous lambda function inside map() in one code line, to find the non-string entries. 
budget[budget.map(lambda x: type(x) != str)]
# Out:
# 16                    [$2,500,000, [, citation needed, ]]
# 100                       [£960,000, [2], ($1.5 million)]
# 135                                     [USD$, 9 million]
# 142      [$23 million (estimated), [, citation needed, ]]
# 151                  [$14 million, [, citation needed, ]]
#                               ...
# 6994                                  [$22, million, [1]]
# 6995                                     [$22.8, million]
# 7015                                  [$36, million, [6]]
# 7018    [$70 million (gross), [3], [4], $59 million (n...
# 7048                                 [$175, million, [4]]
# Name: Budget, Length: 184, dtype: object

# %%
# Convert any lists to strings. 
# use simple space as the joining character and apply join() function only when data points are lists.
budget = budget.map(lambda x: ' '.join(x) if type(x) == list else x)

# %%
# Check the result of joining lists. 
print(budget[16])
print(budget[135])
print(budget[100])
# Out:
# $2,500,000 [ citation needed ]
# USD$ 9 million
# £960,000 [2] ($1.5 million)

# %%
# Remove any values between a dollar sign and a hyphen for budgets given in ranges. 
budget = budget.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)

# %%
# Check the result of removing hyphens.
print(budget[4554])
# Out:
# $88.5 million

# %%
# Create the first form to match the budget data in form "$123.4 million or billion".
form_one = r"\$\s*\d+\.?\d*\s*[mb]illi?on"

# %%
# Count up how many budget values match the first form, ignore upper- lowercase, parse the non-string data to False.
budget.str.contains(form_one, flags=re.IGNORECASE, na=False).sum()
# Out:
# 4363

# %%
# Create the first form to match the budget data in form "$123,456,789"
form_two = r"\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)"

# %%
# Count up how many budget values match the second form, ignore upper- lowercase, parse the non-string data to False.
budget.str.contains(form_two, flags=re.IGNORECASE, na=False).sum()
# Out:
# 339

# %%
# Select the budget values that don't match either forms, using Pandas element-wise logical operators.
matches_form_one = budget.str.contains(form_one, flags=re.IGNORECASE, na=False)
matches_form_two = budget.str.contains(form_two, flags=re.IGNORECASE, na=False)
budget[~matches_form_one & ~matches_form_two]
# Out:
# 136                         Unknown
# 204     60 million Norwegian Kroner
# 478                         Unknown
# 973             $34 [3] [4] million
# 1126               $120 [4] million
# 1226                        Unknown
# 1278                            HBO
# 1374                     £6,000,000
# 1397                     13 million
# 1480                   £2.8 million
# 1734                   CAD2,000,000
# 1913     PHP 85 million (estimated)
# 1948                    102,888,900
# 1953                   3,500,000 DM
# 1973                     ₤2,300,874
# 2281                     $14 milion
# 2451                     ₤6,350,000
# 3144                   € 40 million
# 3360               $150 [6] million
# 3418                        $218.32
# 3802                   £4.2 million
# 3906                            N/A
# 3959                    760,000 USD
# 4470                       19 crore
# 4641                    £17 million
# 5034              $$200 [4] million
# 5055           $155 [2] [3] million
# 5419                $40 [4] million
# 5424                            N/A
# 5447                     £4 million
# 5671                    €14 million
# 5687                   $ dead link]
# 6385               £ 12 million [3]
# 6593                     £3 million
# 6821                  £12.9 million
# 6843                      3.5 crore
# 6895                        919,000
# 7070                   €4.3 million
# Name: Budget, dtype: object

# %%
len(budget[~matches_form_one & ~matches_form_two])
# Out:
# 38

# %%
# Remove the citation references (numbers in square brackets), notice the need to escape brackets as special characters in regex.
# include regex=True to avoid warning message.
budget = budget.str.replace(r'\[\d+\]\s*','', regex=True)

# %%
# Check the remaing budget entries that don't match either forms. 
# Select the budget values that don't match either forms, using Pandas element-wise logical operators.
matches_form_one = budget.str.contains(form_one, flags=re.IGNORECASE, na=False)
matches_form_two = budget.str.contains(form_two, flags=re.IGNORECASE, na=False)
budget[~matches_form_one & ~matches_form_two]
# Out:
# 136                         Unknown
# 204     60 million Norwegian Kroner
# 478                         Unknown
# 1226                        Unknown
# 1278                            HBO
# 1374                     £6,000,000
# 1397                     13 million
# 1480                   £2.8 million
# 1734                   CAD2,000,000
# 1913     PHP 85 million (estimated)
# 1948                    102,888,900
# 1953                   3,500,000 DM
# 1973                     ₤2,300,874
# 2281                     $14 milion
# 2451                     ₤6,350,000
# 3144                   € 40 million
# 3418                        $218.32
# 3802                   £4.2 million
# 3906                            N/A
# 3959                    760,000 USD
# 4470                       19 crore
# 4641                    £17 million
# 5424                            N/A
# 5447                     £4 million
# 5671                    €14 million
# 5687                   $ dead link]
# 6385                  £ 12 million
# 6593                     £3 million
# 6821                  £12.9 million
# 6843                      3.5 crore
# 6895                        919,000
# 7070                   €4.3 million
# Name: Budget, dtype: object

# %%
len(budget[~matches_form_one & ~matches_form_two])
# Out:
# 32

# %%
# now we have all we need to parse the budget values to numeric values. 
# extract the values from budget using str.extract. then apply the parse_dollars to the first col of DF returned by str.extract.
wiki_movies_df['budget'] = budget.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)

# %%
# Check the new 'budget' column values in the DF.
wiki_movies_df['budget']
# Out:
# 0       20000000.0
# 1        6000000.0
# 2       35000000.0
# 3       12000000.0
# 4       25000000.0
#            ...
# 7071    42000000.0
# 7072    60000000.0
# 7073    20000000.0
# 7074     9000000.0
# 7075           NaN
# Name: budget, Length: 7033, dtype: float64

# %%
# Drop the 'Budget' column since it's no longer needed. 
wiki_movies_df.drop('Budget', axis=1, inplace=True)

# %%
# Check DF.
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  Cinematography  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...     Oliver Wood
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...    Mark Plummer
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...   Roger Deakins
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  Carlo Di Palma
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]    Russell Boyd
#
#                                         Release date Running time  \
# 0                  [July 11, 1990, (, 1990-07-11, )]  102 minutes
# 1  [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...  114 minutes
# 2                [August 10, 1990, (, 1990-08-10, )]  113 minutes
# 3              [December 25, 1990, (, 1990-12-25, )]  106 minutes
# 4                                  December 19, 1990   95 minutes
#
#          Country  ...            Director         Distributor  \
# 0  United States  ...        Renny Harlin    20th Century Fox
# 1  United States  ...         James Foley     Avenue Pictures
# 2  United States  ...  Roger Spottiswoode    TriStar Pictures
# 3  United States  ...         Woody Allen      Orion Pictures
# 4             US  ...        John Cornell  Paramount Pictures
#
#                         Editor(s)              Composer(s)  \
# 0                 Michael Tronick  [Cliff Eidelman, Yello]
# 1                 Howard E. Smith            Maurice Jarre
# 2  [John Bloom, Lois Freeman-Fox]            Charles Gross
# 3                  Susan E. Morse                      NaN
# 4                    David Stiven            Maurice Jarre
#
#                    Producer(s)                  Production company(s)  \
# 0   [Steve Perry, Joel Silver]                        Silver Pictures
# 1  [Ric Kidney, Robert Redlin]                        Avenue Pictures
# 2               Daniel Melnick  [Carolco Pictures, IndieProd Company]
# 3              Robert Greenhut                                    NaN
# 4                 John Cornell                                    NaN
#
#                       Writer(s)    imdb_id  box_office      budget
# 0   [David Arnott, James Cappe]  tt0098987  21400000.0  20000000.0
# 1  [James Foley, Robert Redlin]  tt0098994   2700000.0   6000000.0
# 2    [John Eskow, Richard Rush]  tt0099005  57718089.0  35000000.0
# 3                   Woody Allen  tt0099012   7331647.0  12000000.0
# 4                    Paul Hogan  tt0099018   6939946.0  25000000.0
#
# [5 rows x 21 columns]

# %%
# get the df columns. 
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Based on',
#  'Cinematography',
#  'Composer(s)',
#  'Country',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Language',
#  'Producer(s)',
#  'Production company(s)',
#  'Release date',
#  'Running time',
#  'Starring',
#  'Writer(s)',
#  'box_office',
#  'budget',
#  'imdb_id',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %% [markdown]
# ### Parse Release Date in Wiki Data

# %%
# Collect the rows with non-null values release date data, it will be defined as a series, and convert lists to strings.
release_date = wiki_movies_df['Release date'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)

# %%
# Check forms in release date series.
print(release_date.sample(n=5))
# Out:
# 75         August 10, 1990 ( 1990-08-10 ) (United States)
# 575                        October 2, 1992 ( 1992-10-02 )
# 6414    July 30, 2015 ( 2015-07-30 ) ( L.A. Live premi...
# 6119                     February 14, 2014 ( 2014-02-14 )
# 6291    October 4, 2014 ( 2014-10-04 ) ( NYFF ) Decemb...
# Name: Release date, dtype: object

# %%
# # Build the pattern matching forms for release date data. 
# # e.g., form one= January 1, 2000; form two = 2000-01-01; form three = January 2000; form four = 2000.
# form_one = r"[a-zA-Z]+\s+\d+,\s+\d{4}"
# form_two = r"\d{4}(?:.*\d{2})+"
# form_three = r"[A-Za-z]+\s+\d{4}"
# form_four = r"\d{4}"

# %%
# Build the pattern matching forms for release date data. 
# e.g., form one= month, dd, yyyy; form two = yyyy-mm-dd or yyyy/mm/dd; form three = month yyyy; form four = yyyy.
date_form_one = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s[123]?\d,\s\d{4}'
date_form_two = r'\d{4}.[01]\d.[0123]\d'
date_form_three = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d{4}'
date_form_four = r'\d{4}'

# %%
# Extract the matching release dates.
release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})', flags=re.IGNORECASE)
# Out:
#                       0
# 0         July 11, 1990
# 1          May 17, 1990
# 2       August 10, 1990
# 3     December 25, 1990
# 4     December 19, 1990
# ...                 ...
# 7071  December 25, 2018
# 7072  December 11, 2018
# 7073   November 8, 2018
# 7074    August 31, 2018
# 7075      December 2018
#
# [7001 rows x 1 columns]

# %%
# Parse the release date data using the pandas built-in to_datetime(), and create a new release_date col in the wiki_movies_df.
wiki_movies_df['release_date'] = pd.to_datetime(release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})')[0], infer_datetime_format=True)

# %%
# Check the DF.
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  Cinematography  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...     Oliver Wood
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...    Mark Plummer
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...   Roger Deakins
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  Carlo Di Palma
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]    Russell Boyd
#
#                                         Release date Running time  \
# 0                  [July 11, 1990, (, 1990-07-11, )]  102 minutes
# 1  [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...  114 minutes
# 2                [August 10, 1990, (, 1990-08-10, )]  113 minutes
# 3              [December 25, 1990, (, 1990-12-25, )]  106 minutes
# 4                                  December 19, 1990   95 minutes
#
#          Country  ...         Distributor                       Editor(s)  \
# 0  United States  ...    20th Century Fox                 Michael Tronick
# 1  United States  ...     Avenue Pictures                 Howard E. Smith
# 2  United States  ...    TriStar Pictures  [John Bloom, Lois Freeman-Fox]
# 3  United States  ...      Orion Pictures                  Susan E. Morse
# 4             US  ...  Paramount Pictures                    David Stiven
#
#                Composer(s)                  Producer(s)  \
# 0  [Cliff Eidelman, Yello]   [Steve Perry, Joel Silver]
# 1            Maurice Jarre  [Ric Kidney, Robert Redlin]
# 2            Charles Gross               Daniel Melnick
# 3                      NaN              Robert Greenhut
# 4            Maurice Jarre                 John Cornell
#
#                    Production company(s)                     Writer(s)  \
# 0                        Silver Pictures   [David Arnott, James Cappe]
# 1                        Avenue Pictures  [James Foley, Robert Redlin]
# 2  [Carolco Pictures, IndieProd Company]    [John Eskow, Richard Rush]
# 3                                    NaN                   Woody Allen
# 4                                    NaN                    Paul Hogan
#
#      imdb_id  box_office      budget  release_date
# 0  tt0098987  21400000.0  20000000.0    1990-07-11
# 1  tt0098994   2700000.0   6000000.0    1990-05-17
# 2  tt0099005  57718089.0  35000000.0    1990-08-10
# 3  tt0099012   7331647.0  12000000.0    1990-12-25
# 4  tt0099018   6939946.0  25000000.0    1990-12-19
#
# [5 rows x 22 columns]

# %%
wiki_movies_df['release_date'].isnull().sum()
# Out:
# 32

# %%
wiki_movies_df.loc[wiki_movies_df['release_date'].isnull()]
# Out:
#                                                     url  year  \
# 212   https://en.wikipedia.org/wiki/Snake_Eater_II:_...  1990
# 1044  https://en.wikipedia.org/wiki/No_Dessert,_Dad,...  1994
# 1173  https://en.wikipedia.org/wiki/Black_Scorpion_(...  1995
# 1234    https://en.wikipedia.org/wiki/Flirt_(1995_film)  1995
# 1302  https://en.wikipedia.org/wiki/Let_It_Be_Me_(19...  1995
# 1346  https://en.wikipedia.org/wiki/No_Exit_(1995_film)  1995
# 1635        https://en.wikipedia.org/wiki/Listen_(film)  1996
# 1644       https://en.wikipedia.org/wiki/Magenta_(film)  1996
# 1777  https://en.wikipedia.org/wiki/Your_Studio_and_You  1996
# 1836  https://en.wikipedia.org/wiki/A_Brooklyn_State...  1997
# 1922      https://en.wikipedia.org/wiki/Highball_(film)  1997
# 1968  https://en.wikipedia.org/wiki/Little_Red_Ridin...  1997
# 2102        https://en.wikipedia.org/wiki/Velocity_Trap  1997
# 2109  https://en.wikipedia.org/wiki/Weapons_of_Mass_...  1997
# 2243   https://en.wikipedia.org/wiki/Melting_Pot_(film)  1998
# 2764  https://en.wikipedia.org/wiki/The_Visit_(2000_...  2000
# 2993     https://en.wikipedia.org/wiki/West_47th_Street  2001
# 3042         https://en.wikipedia.org/wiki/Ciao_America  2002
# 3190   https://en.wikipedia.org/wiki/Stevie_(2002_film)  2002
# 3240         https://en.wikipedia.org/wiki/Anne_B._Real  2003
# 3609  https://en.wikipedia.org/wiki/Return_to_Sender...  2004
# 3946  https://en.wikipedia.org/wiki/The_Beach_Party_...  2006
# 3997         https://en.wikipedia.org/wiki/Crude_Impact  2006
# 4004  https://en.wikipedia.org/wiki/Danny_Roane:_Fir...  2006
# 4142  https://en.wikipedia.org/wiki/Live_Free_or_Die...  2006
# 4209           https://en.wikipedia.org/wiki/Quick_Pick  2006
# 4252      https://en.wikipedia.org/wiki/Sonhos_de_Peixe  2006
# 5508    https://en.wikipedia.org/wiki/California_Winter  2012
# 5557  https://en.wikipedia.org/wiki/Don%27t_Change_t...  2012
# 5583  https://en.wikipedia.org/wiki/For_the_Love_of_...  2012
# 5880         https://en.wikipedia.org/wiki/Hit_%26_Stay  2013
# 6797  https://en.wikipedia.org/wiki/The_Man_Who_Inve...  2017
#
#                                   imdb_link  \
# 212   https://www.imdb.com/title/tt0102950/
# 1044  https://www.imdb.com/title/tt0110676/
# 1173  https://www.imdb.com/title/tt0112519/
# 1234  https://www.imdb.com/title/tt0113080/
# 1302  https://www.imdb.com/title/tt0113638/
# 1346  https://www.imdb.com/title/tt0113990/
# 1635  https://www.imdb.com/title/tt2910992/
# 1644  https://www.imdb.com/title/tt0116956/
# 1777  https://www.imdb.com/title/tt0159144/
# 1836  https://www.imdb.com/title/tt0118782/
# 1922  https://www.imdb.com/title/tt0119291/
# 1968  https://www.imdb.com/title/tt0119552/
# 2102  https://www.imdb.com/title/tt0120435/
# 2109  https://www.imdb.com/title/tt0120487/
# 2243  https://www.imdb.com/title/tt0127020/
# 2764  https://www.imdb.com/title/tt0199129/
# 2993  https://www.imdb.com/title/tt0357309/
# 3042  https://www.imdb.com/title/tt0275263/
# 3190  https://www.imdb.com/title/tt0334416/
# 3240  https://www.imdb.com/title/tt0315775/
# 3609  https://www.imdb.com/title/tt0396190/
# 3946  https://www.imdb.com/title/tt0443441/
# 3997  https://www.imdb.com/title/tt0932519/
# 4004  https://www.imdb.com/title/tt0470995/
# 4142  https://www.imdb.com/title/tt0432318/
# 4209  https://www.imdb.com/title/tt0805594/
# 4252  https://www.imdb.com/title/tt0423232/
# 5508  https://www.imdb.com/title/tt1826627/
# 5557  https://www.imdb.com/title/tt2040326/
# 5583  https://www.imdb.com/title/tt1730294/
# 5880  https://www.imdb.com/title/tt2252038/
# 6797  https://www.imdb.com/title/tt6225520/
#
#                                          title  \
# 212            Snake Eater II: The Drug Buster
# 1044    No Dessert, Dad, till You Mow the Lawn
# 1173                            Black Scorpion
# 1234                                     Flirt
# 1302                              Let It Be Me
# 1346                                   No Exit
# 1635                                    Listen
# 1644                                   Magenta
# 1777                       Your Studio and You
# 1836                  A Brooklyn State of Mind
# 1922                                  Highball
# 1968                    Little Red Riding Hood
# 2102                             Velocity Trap
# 2109               Weapons of Mass Distraction
# 2243                               Melting Pot
# 2764                                 The Visit
# 2993                          West 47th Street
# 3042                              Ciao America
# 3190                                    Stevie
# 3240                              Anne B. Real
# 3609                          Return to Sender
# 3946  The Beach Party at the Threshold of Hell
# 3997                              Crude Impact
# 4004          Danny Roane: First Time Director
# 4142                          Live Free or Die
# 4209                                Quick Pick
# 4252                           Sonhos de peixe
# 5508                         California Winter
# 5557                  Don't Change the Subject
# 5583                     For the Love of Money
# 5880                                Hit & Stay
# 6797            The Man Who Invented Christmas
#
#                                                Based on  \
# 212                                                 NaN
# 1044                                                NaN
# 1173                                                NaN
# 1234                                                NaN
# 1302                                                NaN
# 1346                                                NaN
# 1635                                                NaN
# 1644                                                NaN
# 1777                                                NaN
# 1836                                                NaN
# 1922                                                NaN
# 1968                                                NaN
# 2102                                                NaN
# 2109                                                NaN
# 2243                                                NaN
# 2764                                                NaN
# 2993                                                NaN
# 3042                                                NaN
# 3190                                                NaN
# 3240                                                NaN
# 3609                                                NaN
# 3946                                                NaN
# 3997                                                NaN
# 4004                                                NaN
# 4142                                                NaN
# 4209                                                NaN
# 4252                                                NaN
# 5508                                                NaN
# 5557                                                NaN
# 5583                                                NaN
# 5880                                                NaN
# 6797  [The Man Who Invented Christmas, by, Les Stand...
#
#                                                Starring  \
# 212                        [Lorenzo Lamas, Ron Palillo]
# 1044                        [Robert Hays, Joanna Kerns]
# 1173     [Joan Severance, Bruce Abbott, Garrett Morris]
# 1234            [Bill Sage, Dwight Ewell, Miho Nikaido]
# 1302                                                NaN
# 1346                   [Jeff Wincott, Sven-Ole Thorsen]
# 1635  [Joshua Mikel, Julie Moss, Avery Pohl, Julie M...
# 1644  [Julian McMahon, Alison Storry, Marklen Kenned...
# 1777  [Sylvester Stallone, Demi Moore, Steven Spielb...
# 1836                                                NaN
# 1922  [Justine Bateman, Peter Bogdanovich, Chris Eig...
# 1968  [Christina Ricci, Timour Bourtasenkov, Quentin...
# 2102       [Olivier Gruner, Alicia Coppola, Ken Olandt]
# 2109                                                NaN
# 2243                                                NaN
# 2764  [Hill Harper, Billy Dee Williams, Obba Babatun...
# 2993                                                NaN
# 3042                                                NaN
# 3190                                                NaN
# 3240      [David Zayas, Carlos Leon, Janice Richardson]
# 3609         [Aidan Quinn, Connie Nielsen, Mark Holton]
# 3946  [Kevin Wheatley, Bill English, Chandler Parker...
# 3997                                                NaN
# 4004  [Andy Dick, Frankie Muniz, Jack Black, Sara Ru...
# 4142  [Aaron Stanford, Paul Schneider, Ebon Moss-Bac...
# 4209  [John Bryant, Anna Moreno-Nava, Angelina Asser...
# 4252  [José Maria Alves, Rubia Rafaelle, Phellipe Ha...
# 5508                                                NaN
# 5557                                                NaN
# 5583  [Yehuda Levi, Edward Furlong, James Caan, Jeff...
# 5880  [The Catonsville Nine, ,, The Baltimore Four, ...
# 6797  [Dan Stevens, Christopher Plummer, Jonathan Pr...
#
#                                   Cinematography Release date    Running time  \
# 212                              Glen MacPherson          NaN      93 minutes
# 1044                                         NaN          NaN         89 min.
# 1173                                Geoff George          NaN         90 min.
# 1234                             Michael Spiller          NaN      83 minutes
# 1302                           Miroslav Ondrícek          NaN             NaN
# 1346                                 Russ Goozee          NaN      96 minutes
# 1635                                 F.C.Rabbath          NaN      90 Minutes
# 1644                       Mark Anthony Galluzzo          NaN      91 minutes
# 1777                              Kenny Gioseffi          NaN  approx. 14 min
# 1836                                  Ken Kelsch          NaN             NaN
# 1922                            Steven Bernstein          NaN     110 minutes
# 1968                                Scott Ramsey          NaN      12 minutes
# 2102                          Philip D. Schwartz          NaN      89 minutes
# 2109                                         NaN          NaN         100 min
# 2243                                Arturo Smith          NaN     104 minutes
# 2764                           John L. Demps Jr.          NaN     107 minutes
# 2993            Bill Lichtenstein, Mark Peterson          NaN          1h 48m
# 3042                         Giulio Pietromarchi          NaN             NaN
# 3190  [Dana Kupper, Gordon Quinn, Peter Gilbert]          NaN         144 min
# 3240                                         NaN          NaN      91 minutes
# 3609                                         NaN          NaN             NaN
# 3946                              Cameron Pearce          NaN             NaN
# 3997                             Sharon Anderson          NaN      97 minutes
# 4004                                         NaN          NaN      83 minutes
# 4142                                         NaN          NaN      89 minutes
# 4209                [Tony Colomar, Will Vazquez]          NaN      87 minutes
# 4252                               Andrij Parekh          NaN         111 min
# 5508                                         NaN          NaN             NaN
# 5557                               Jay Lafayette          NaN      97 minutes
# 5583                              Andrzej Sekuła          NaN      93 minutes
# 5880                                 Skizz Cyzyk          NaN      97 minutes
# 6797                                Ben Smithard          NaN             NaN
#
#                                    Country  ...  \
# 212                                 Canada  ...
# 1044                                   NaN  ...
# 1173                         United States  ...
# 1234  [United States, Germany, Japan, [1]]  ...
# 1302                                   NaN  ...
# 1346                                Canada  ...
# 1635                         United States  ...
# 1644                         United States  ...
# 1777                         United States  ...
# 1836                                   NaN  ...
# 1922                         United States  ...
# 1968                         United States  ...
# 2102                         United States  ...
# 2109                         United States  ...
# 2243                         United States  ...
# 2764                                   NaN  ...
# 2993                         United States  ...
# 3042                                   NaN  ...
# 3190                         United States  ...
# 3240                                   NaN  ...
# 3609                    [Denmark, USA, UK]  ...
# 3946                                   NaN  ...
# 3997                         United States  ...
# 4004                         United States  ...
# 4142                         United States  ...
# 4209                         United States  ...
# 4252       [United States, Brazil, Russia]  ...
# 5508                         United States  ...
# 5557                         United States  ...
# 5583                         United States  ...
# 5880                         United States  ...
# 6797                                   NaN  ...
#
#                                             Distributor  \
# 212                                                 NaN
# 1044                                                NaN
# 1173                                           Showtime
# 1234                             Pandora Film (Germany)
# 1302                                                NaN
# 1346                        No Exit Productions Limited
# 1635                                                NaN
# 1644                                                NaN
# 1777                                  Universal Studios
# 1836                                                NaN
# 1922                                                NaN
# 1968                                                NaN
# 2102                                 New City Releasing
# 2109                                                NaN
# 2243  A-Pix Entertainment, Ardustry Home Entertainme...
# 2764                                                NaN
# 2993                                                NaN
# 3042                                                NaN
# 3190                                   Kartemquin Films
# 3240                          [Screen Media, Universal]
# 3609                                                NaN
# 3946                                                NaN
# 3997                                                NaN
# 4004                                          Lionsgate
# 4142                                                NaN
# 4209                                                NaN
# 4252                                       Unison Films
# 5508                                                NaN
# 5557                                                NaN
# 5583                                                NaN
# 5880                                                NaN
# 6797  [Elevation Pictures, (Canada), Wildcard Distri...
#
#                                               Editor(s)  \
# 212                                                 NaN
# 1044                                                NaN
# 1173                      [Tom Petersen, Gwyneth Gibby]
# 1234                 [Hal Hartley, Steve Hamilton, [1]]
# 1302         [Patricia Bowers, Ray Hubley, Bill Pankow]
# 1346                                      David Ransley
# 1635                                                NaN
# 1644                                       Paul Osborne
# 1777                                                NaN
# 1836                                                NaN
# 1922                                 J. Kathleen Gibson
# 1968                                                NaN
# 2102                                 Christian McIntire
# 2109                                     Zach Staenberg
# 2243                                                NaN
# 2764                                                NaN
# 2993                                      Spiro Lampros
# 3042                                                NaN
# 3190                        [Steve James,, Bill Haugse]
# 3240                                                NaN
# 3609                                                NaN
# 3946                                     Cameron Pearce
# 3997  [Sharon Anderson, Pamela Spitzer, James Jandak...
# 4004                                                NaN
# 4142                                                NaN
# 4209                                       Will Vazquez
# 4252                   [Adam Walsh, Kirill Mikhanovsky]
# 5508                                                NaN
# 5557                                      Gail Yasunaga
# 5583                      [Karl T. Hirsch, Eric Strand]
# 5880                                        Skizz Cyzyk
# 6797                 [Stephen O'Connell, Jamie Pearson]
#
#                                             Composer(s)  \
# 212                                        John Massari
# 1044                                                NaN
# 1173                                        Kevin Kiner
# 1234                 [Hal Hartley, Jeffrey Taylor, [1]]
# 1302                                                NaN
# 1346                                          Ken Greer
# 1635  [Tony Anderson, Sean Beeson, Valentin Boomes, ...
# 1644      [Harald Kloser, Thomas Schobel (co-composer)]
# 1777                                                NaN
# 1836                                          Paul Zaza
# 1922                                                NaN
# 1968                                                NaN
# 2102         [Jim Goodwin, Richard McHugh, Mike Slamer]
# 2109                                          Don Davis
# 2243                                                NaN
# 2764                                                NaN
# 2993                                                NaN
# 3042                                   Andrea Morricone
# 3190                                        Dirk Powell
# 3240                                                NaN
# 3609                             Harry Gregson-Williams
# 3946                                    Russ Howard III
# 3997                                                NaN
# 4004                                                NaN
# 4142                                                NaN
# 4209                                                NaN
# 4252                                                NaN
# 5508                                                NaN
# 5557                [Charlie Recksieck,, The Bigfellas]
# 5583                                      Jerome Dillon
# 5880                                                NaN
# 6797                                      Mychael Danna
#
#                                             Producer(s)  \
# 212                                                 NaN
# 1044                                                NaN
# 1173                                       Mike Elliott
# 1234                                           Ted Hope
# 1302                                                NaN
# 1346                                                NaN
# 1635        [F.C.Rabbath, Vanessa Vandy, Adam Bertocci]
# 1644                          Bill and Michael Talerico
# 1777                                                NaN
# 1836                                                NaN
# 1922                                    Joel Castleberg
# 1968                    [Rocco Caruso, Jasmine Kosovic]
# 2102  [Christian McIntire, Ken Olandt, Phillip J. Ro...
# 2109                                       Sean Ryerson
# 2243                                                NaN
# 2764                             Jordan Walker-Pearlman
# 2993                        Lichtenstein Creative Media
# 3042                                                NaN
# 3190           [Steve James, Adam Singer, Gordon Quinn]
# 3240                                          Luis Moro
# 3609                                                NaN
# 3946                         [Jamie Bullock, Ryan Turi]
# 3997                                                NaN
# 4004                                                NaN
# 4142                                                NaN
# 4209                                       Will Vazquez
# 4252  [Jacob Michelson, Fernanda de Capua, Eliane Fe...
# 5508                                                NaN
# 5557                              Matt Ima, Fiona Walsh
# 5583                      [Izek Shomof, Jenna Mattison]
# 5880                                         Joe Tropea
# 6797  [Robert Mickelson, Ian Sharples, Paula Mazur, ...
#
#                 Production company(s)  \
# 212                               NaN
# 1044                              NaN
# 1173                     New Horizons
# 1234                     Good Machine
# 1302                              NaN
# 1346                              NaN
# 1635            F.C.Rabbath Creations
# 1644                              NaN
# 1777                              NaN
# 1836                              NaN
# 1922         Shoreline  Entertainment
# 1968                              NaN
# 2102                              NaN
# 2109                              NaN
# 2243                              NaN
# 2764                              NaN
# 2993                              NaN
# 3042                              NaN
# 3190                              NaN
# 3240                              NaN
# 3609                              NaN
# 3946                              NaN
# 3997                              NaN
# 4004                              NaN
# 4142                              NaN
# 4209                              NaN
# 4252                              NaN
# 5508                              NaN
# 5557                              NaN
# 5583             All Cash Productions
# 5880                              NaN
# 6797  [Parallel Films, Rhombus Media]
#
#                                               Writer(s)    imdb_id box_office  \
# 212      [Don Carmody, John Dunning, Michael Paseornek]  tt0102950        NaN
# 1044                    [Jennifer Moran,, Martha Moran]  tt0110676        NaN
# 1173                                    Craig J. Nevius  tt0112519        NaN
# 1234                                        Hal Hartley  tt0113080        NaN
# 1302                                  Eleanor Bergstein  tt0113638        NaN
# 1346                          [John Lawson, Damian Lee]  tt0113990        NaN
# 1635                                        F.C.Rabbath  tt2910992        NaN
# 1644                                  Gregory C. Haynes  tt0116956        NaN
# 1777                          [Trey Parker, Matt Stone]  tt0159144        NaN
# 1836                                                NaN  tt0118782        NaN
# 1922  [Noah Baumbach (as Jesse Carter), Carlos Jacot...  tt0119291        NaN
# 1968                                       David Kaplan  tt0119552        NaN
# 2102                [Patrick Phillips, Phillip J. Roth]  tt0120435        NaN
# 2109                                      Larry Gelbart  tt0120487        NaN
# 2243                           [Mark Kemble, Tom Musca]  tt0127020        NaN
# 2764  [Kosmond Russell, (play), Jordan Walker-Pearlm...  tt0199129        NaN
# 2993                                                NaN  tt0357309        NaN
# 3042                                                NaN  tt0275263        NaN
# 3190                                                NaN  tt0334416        NaN
# 3240                                      Antonio Macia  tt0315775        NaN
# 3609                        Neal Purvis and Robert Wade  tt0396190        NaN
# 3946                                     Kevin Wheatley  tt0443441        NaN
# 3997                                  James Jandak Wood  tt0932519        NaN
# 4004                                          Andy Dick  tt0470995        NaN
# 4142                          [Gregg Kavet, Andy Robin]  tt0432318        NaN
# 4209                 [Will Vazquez, Rafael Diaz-Wagner]  tt0805594        NaN
# 4252                                 Kirill Mikhanovsky  tt0423232        NaN
# 5508                                         Odin Ozdil  tt1826627        NaN
# 5557                                                NaN  tt2040326        NaN
# 5583                                      Michael Micco  tt1730294        NaN
# 5880                                                NaN  tt2252038        NaN
# 6797                                        Susan Coyne  tt6225520        NaN
#
#      budget  release_date
# 212     NaN           NaT
# 1044    NaN           NaT
# 1173    NaN           NaT
# 1234    NaN           NaT
# 1302    NaN           NaT
# 1346    NaN           NaT
# 1635    NaN           NaT
# 1644    NaN           NaT
# 1777    NaN           NaT
# 1836    NaN           NaT
# 1922    NaN           NaT
# 1968    NaN           NaT
# 2102    NaN           NaT
# 2109    NaN           NaT
# 2243    NaN           NaT
# 2764    NaN           NaT
# 2993    NaN           NaT
# 3042    NaN           NaT
# 3190    NaN           NaT
# 3240    NaN           NaT
# 3609    NaN           NaT
# 3946    NaN           NaT
# 3997    NaN           NaT
# 4004    NaN           NaT
# 4142    NaN           NaT
# 4209    NaN           NaT
# 4252    NaN           NaT
# 5508    NaN           NaT
# 5557    NaN           NaT
# 5583    NaN           NaT
# 5880    NaN           NaT
# 6797    NaN           NaT
#
# [32 rows x 22 columns]

# %%
# Drop the original 'Release date' column from the DF. 
wiki_movies_df.drop('Release date', axis=1, inplace=True)

# %%
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  Cinematography  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...     Oliver Wood
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...    Mark Plummer
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...   Roger Deakins
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  Carlo Di Palma
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]    Russell Boyd
#
#   Running time        Country        Language  ...  \
# 0  102 minutes  United States         English  ...
# 1  114 minutes  United States         English  ...
# 2  113 minutes  United States  [English, Lao]  ...
# 3  106 minutes  United States         English  ...
# 4   95 minutes             US         English  ...
#
#                         Editor(s)              Composer(s)  \
# 0                 Michael Tronick  [Cliff Eidelman, Yello]
# 1                 Howard E. Smith            Maurice Jarre
# 2  [John Bloom, Lois Freeman-Fox]            Charles Gross
# 3                  Susan E. Morse                      NaN
# 4                    David Stiven            Maurice Jarre
#
#                    Producer(s)                  Production company(s)  \
# 0   [Steve Perry, Joel Silver]                        Silver Pictures
# 1  [Ric Kidney, Robert Redlin]                        Avenue Pictures
# 2               Daniel Melnick  [Carolco Pictures, IndieProd Company]
# 3              Robert Greenhut                                    NaN
# 4                 John Cornell                                    NaN
#
#                       Writer(s)    imdb_id  box_office      budget  \
# 0   [David Arnott, James Cappe]  tt0098987  21400000.0  20000000.0
# 1  [James Foley, Robert Redlin]  tt0098994   2700000.0   6000000.0
# 2    [John Eskow, Richard Rush]  tt0099005  57718089.0  35000000.0
# 3                   Woody Allen  tt0099012   7331647.0  12000000.0
# 4                    Paul Hogan  tt0099018   6939946.0  25000000.0
#
#    release_date  running_time
# 0    1990-07-11         102.0
# 1    1990-05-17         114.0
# 2    1990-08-10         113.0
# 3    1990-12-25         106.0
# 4    1990-12-19          95.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Parse Running Time in Wiki Data

# %%
# Collect the rows with non-null values of running time data, it will be defined as a series, and convert lists to strings.
running_time = wiki_movies_df['Running time'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)

# %%
len(running_time)
# Out:
# 6894

# %%
running_time.sample(n=20)
# Out:
# 3015     91 minutes
# 4066        100 min
# 2549    114 minutes
# 5661     92 minutes
# 2040     92 minutes
# 856      95 minutes
# 5460    120 minutes
# 669     126 minutes
# 2996     96 minutes
# 2222     98 minutes
# 1156        87 min.
# 5190    123 minutes
# 3617     86 minutes
# 1673     95 minutes
# 2543     96 minutes
# 6191    134 minutes
# 5537    165 minutes
# 3808    144 minutes
# 4398     90 minutes
# 402     132 minutes
# Name: Running time, dtype: object

# %%
# Find out how many running times look exactly like '100 minutes' by using string boundaries. 
running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE, na=False).sum()
# Out:
# 6528

# %%
# Find out what the remaining (366) running times look like. 
running_time[running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE, na=False) != True]
# Out:
# 9                                                 102 min
# 26                                                 93 min
# 28                                                32 min.
# 34                                                101 min
# 35                                                 97 min
#                               ...
# 6500       114 minutes [1] 120 minutes (extended edition)
# 6643                                             104 mins
# 6709    90 minutes (theatrical) [1] 91 minutes (unrate...
# 7057    108 minutes (Original cut) 98 minutes (UK cut)...
# 7075                Variable; 90 minutes for default path
# Name: Running time, Length: 366, dtype: object

# %%
# Make the pattern match form more general 
# by only marking the beginning of the string and accepting other abb. of 'minutes' by only searching up to the letter 'm'.
running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE, na=False).sum()
# Out:
# 6877

# %%
# Get the remaining (17) entries that don't match the general pattern. 
running_time[running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE, na=False) != True]
# Out:
# 668                     UK:84 min (DVD version) US:86 min
# 727                         78-102 min (depending on cut)
# 840                       Varies (79 [3] –84 [1] minutes)
# 1347                                              25 : 03
# 1443    United States: 77 minutes Argentina: 94 minute...
# 1499                                            1hr 35min
# 1551                                               varies
# 1774                    Netherlands:96 min, Canada:95 min
# 1777                                       approx. 14 min
# 2273                                           1 h 43 min
# 2993                                               1h 48m
# 3925                                              4 hours
# 4425    US domestic version: 86 minutes Original versi...
# 4967    Theatrical cut: 97 minutes Unrated cut: 107 mi...
# 5424                    115 [1] /123 [2] /128 [3] minutes
# 5447                                    1 hour 32 minutes
# 7075                Variable; 90 minutes for default path
# Name: Running time, dtype: object

# %%
# Create a form that matches the hour + minute pattern witn one regex.
hour_min_form = r'\d+\s*ho?u?r?s?\s*\d*'

# %%
# Extract the running time data, only capture the digits, allowing for both possible patterns,
# Relax the first minutes form of how that pattern should start at the beginning of the string by removing ^.
running_time_extract = running_time.str.extract(r'(\d+)\s*ho?u?r?s?\s*(\d*)|(\d+)\s*m')

# %%
# Check the 3 digits groups captured from running time data. 
running_time_extract
# Out:
#         0    1    2
# 0     NaN  NaN  102
# 1     NaN  NaN  114
# 2     NaN  NaN  113
# 3     NaN  NaN  106
# 4     NaN  NaN   95
# ...   ...  ...  ...
# 7071  NaN  NaN   90
# 7072  NaN  NaN  132
# 7073  NaN  NaN  120
# 7074  NaN  NaN  123
# 7075  NaN  NaN   90
#
# [6894 rows x 3 columns]

# %%
running_time_extract.sample(n=5)
# Out:
#         0    1    2
# 3494  NaN  NaN   98
# 2187  NaN  NaN  124
# 3424  NaN  NaN  104
# 912   NaN  NaN   48
# 3987  NaN  NaN  107

# %%
running_time
# Out:
# 0                                 102 minutes
# 1                                 114 minutes
# 2                                 113 minutes
# 3                                 106 minutes
# 4                                  95 minutes
#                         ...
# 7071                               90 minutes
# 7072                              132 minutes
# 7073                              120 minutes
# 7074                              123 minutes
# 7075    Variable; 90 minutes for default path
# Name: Running time, Length: 6894, dtype: object

# %%
len(running_time_extract)
# Out:
# 6894

# %%
running_time_extract.iloc[-5:]
# Out:
#         0    1    2
# 7071  NaN  NaN   90
# 7072  NaN  NaN  132
# 7073  NaN  NaN  120
# 7074  NaN  NaN  123
# 7075  NaN  NaN   90

# %%
running_time_extract.loc[1499]
# Out:
# 0      1
# 1     35
# 2    NaN
# Name: 1499, dtype: object

# %%
running_time_extract.loc[running_time_extract[0].notnull() == True]
# Out:
#       0   1    2
# 1499  1  35  NaN
# 2273  1  43  NaN
# 2993  1  48  NaN
# 3925  4      NaN
# 5447  1  32  NaN

# %%
# form catpured only the first occurence of time in the entry.
running_time_extract.loc[1774]
# Out:
# 0    NaN
# 1    NaN
# 2     96
# Name: 1774, dtype: object

# %%
# Convert running_time string entries to numeric values, coerce errors to turn empty strings to NaN, then change NaNs to zeros.
running_time_extract = running_time_extract.apply(lambda col: pd.to_numeric(col, errors='coerce')).fillna(0)

# %%
# Check results
running_time_extract
# Out:
#         0    1      2
# 0     0.0  0.0  102.0
# 1     0.0  0.0  114.0
# 2     0.0  0.0  113.0
# 3     0.0  0.0  106.0
# 4     0.0  0.0   95.0
# ...   ...  ...    ...
# 7071  0.0  0.0   90.0
# 7072  0.0  0.0  132.0
# 7073  0.0  0.0  120.0
# 7074  0.0  0.0  123.0
# 7075  0.0  0.0   90.0
#
# [6894 rows x 3 columns]

# %%
# Convert the hour and the minute capture groups to minutes if the pure minutes capture group is zero.
# Save the output to wiki_movies_df.
wiki_movies_df['running_time'] = running_time_extract.apply(lambda row: row[0]*60 + row[1] if row[2] == 0 else row[2], axis=1)

# %%
# Check the new 'running_time' col in df.
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  Cinematography  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...     Oliver Wood
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...    Mark Plummer
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...   Roger Deakins
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  Carlo Di Palma
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]    Russell Boyd
#
#                                         Release date Running time  \
# 0                  [July 11, 1990, (, 1990-07-11, )]  102 minutes
# 1  [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...  114 minutes
# 2                [August 10, 1990, (, 1990-08-10, )]  113 minutes
# 3              [December 25, 1990, (, 1990-12-25, )]  106 minutes
# 4                                  December 19, 1990   95 minutes
#
#          Country  ...                       Editor(s)  \
# 0  United States  ...                 Michael Tronick
# 1  United States  ...                 Howard E. Smith
# 2  United States  ...  [John Bloom, Lois Freeman-Fox]
# 3  United States  ...                  Susan E. Morse
# 4             US  ...                    David Stiven
#
#                Composer(s)                  Producer(s)  \
# 0  [Cliff Eidelman, Yello]   [Steve Perry, Joel Silver]
# 1            Maurice Jarre  [Ric Kidney, Robert Redlin]
# 2            Charles Gross               Daniel Melnick
# 3                      NaN              Robert Greenhut
# 4            Maurice Jarre                 John Cornell
#
#                    Production company(s)                     Writer(s)  \
# 0                        Silver Pictures   [David Arnott, James Cappe]
# 1                        Avenue Pictures  [James Foley, Robert Redlin]
# 2  [Carolco Pictures, IndieProd Company]    [John Eskow, Richard Rush]
# 3                                    NaN                   Woody Allen
# 4                                    NaN                    Paul Hogan
#
#      imdb_id  box_office      budget release_date  running_time
# 0  tt0098987  21400000.0  20000000.0   1990-07-11         102.0
# 1  tt0098994   2700000.0   6000000.0   1990-05-17         114.0
# 2  tt0099005  57718089.0  35000000.0   1990-08-10         113.0
# 3  tt0099012   7331647.0  12000000.0   1990-12-25         106.0
# 4  tt0099018   6939946.0  25000000.0   1990-12-19          95.0
#
# [5 rows x 23 columns]

# %%
# Check the success of the conversion on one of the entries with hour, minute running time.
wiki_movies_df.loc[1499]
# Out:
# url                      https://en.wikipedia.org/wiki/Christmas_Every_Day
# year                                                                  1996
# imdb_link                            https://www.imdb.com/title/tt0115891/
# title                                                  Christmas Every Day
# Based on                                                               NaN
# Starring                 [Erik von Detten, Bess Armstrong, Robert Hays,...
# Cinematography                                               Gideon Porath
# Release date                     [December 1, 1996, (, 1996-12-01, ), [1]]
# Running time                                                     1hr 35min
# Country                                                      United States
# Language                                                               NaN
# Director                                                      Larry Peerce
# Distributor                                 Disney-ABC Domestic Television
# Editor(s)                                                Jerrold L. Ludwig
# Composer(s)                                               Billy Goldenberg
# Producer(s)              [Gary M. Goodman, Barry Rosen, John Byers (co-...
# Production company(s)    [Goodman/Rosen Productions, MTM Enterprises, I...
# Writer(s)                                   [Stephen Alix, Nancey Silvers]
# imdb_id                                                          tt0115891
# box_office                                                             NaN
# budget                                                                 NaN
# release_date                                           1996-12-01 00:00:00
# running_time                                                          95.0
# Name: 1499, dtype: object

# %%
# Drop original 'Running time' column from the dataset. 
wiki_movies_df.drop('Running time', axis=1, inplace=True)

# %%
# Check the completely clean Wikipedia dataset.
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  Cinematography  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...     Oliver Wood
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...    Mark Plummer
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...   Roger Deakins
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  Carlo Di Palma
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]    Russell Boyd
#
#          Country        Language            Director  ...  \
# 0  United States         English        Renny Harlin  ...
# 1  United States         English         James Foley  ...
# 2  United States  [English, Lao]  Roger Spottiswoode  ...
# 3  United States         English         Woody Allen  ...
# 4             US         English        John Cornell  ...
#
#                         Editor(s)              Composer(s)  \
# 0                 Michael Tronick  [Cliff Eidelman, Yello]
# 1                 Howard E. Smith            Maurice Jarre
# 2  [John Bloom, Lois Freeman-Fox]            Charles Gross
# 3                  Susan E. Morse                      NaN
# 4                    David Stiven            Maurice Jarre
#
#                    Producer(s)                  Production company(s)  \
# 0   [Steve Perry, Joel Silver]                        Silver Pictures
# 1  [Ric Kidney, Robert Redlin]                        Avenue Pictures
# 2               Daniel Melnick  [Carolco Pictures, IndieProd Company]
# 3              Robert Greenhut                                    NaN
# 4                 John Cornell                                    NaN
#
#                       Writer(s)    imdb_id  box_office      budget  \
# 0   [David Arnott, James Cappe]  tt0098987  21400000.0  20000000.0
# 1  [James Foley, Robert Redlin]  tt0098994   2700000.0   6000000.0
# 2    [John Eskow, Richard Rush]  tt0099005  57718089.0  35000000.0
# 3                   Woody Allen  tt0099012   7331647.0  12000000.0
# 4                    Paul Hogan  tt0099018   6939946.0  25000000.0
#
#    release_date running_time
# 0    1990-07-11        102.0
# 1    1990-05-17        114.0
# 2    1990-08-10        113.0
# 3    1990-12-25        106.0
# 4    1990-12-19         95.0
#
# [5 rows x 21 columns]

# %%
# Get the clean columns. 
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Based on',
#  'Cinematography',
#  'Composer(s)',
#  'Country',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Language',
#  'Producer(s)',
#  'Production company(s)',
#  'Starring',
#  'Writer(s)',
#  'box_office',
#  'budget',
#  'imdb_id',
#  'imdb_link',
#  'release_date',
#  'running_time',
#  'title',
#  'url',
#  'year']
